# %%
import setup
setup.init_django()

# %%
import helpers.clients as helper_clients

# %%
dataset_a = helper_clients.AlphaVantageAPIClient().get_stock_data()

# %%
dataset_b = helper_clients.PolygonAPIClient().get_stock_data()

# %%
dataset_a
# Out:
# [{'open_price': Decimal('185.0685'),
#   'close_price': Decimal('184.9788'),
#   'high_price': Decimal('185.0685'),
#   'low_price': Decimal('184.9489'),
#   'number_of_trades': None,
#   'volume': 2358,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8991'),
#   'close_price': Decimal('184.9290'),
#   'high_price': Decimal('185.0485'),
#   'low_price': Decimal('184.8991'),
#   'number_of_trades': None,
#   'volume': 200,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8194'),
#   'close_price': Decimal('184.8593'),
#   'high_price': Decimal('185.0485'),
#   'low_price': Decimal('184.8194'),
#   'number_of_trades': None,
#   'volume': 4017,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8095'),
#   'close_price': Decimal('184.8294'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7796'),
#   'number_of_trades': None,
#   'volume': 582,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7895'),
#   'close_price': Decimal('184.7995'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7845'),
#   'number_of_trades': None,
#   'volume': 365,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8194'),
#   'close_price': Decimal('184.7995'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 1167,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8144'),
#   'close_price': Decimal('184.8294'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 1195,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8294'),
#   'close_price': Decimal('184.7995'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.6999'),
#   'number_of_trades': None,
#   'volume': 375,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7995'),
#   'close_price': Decimal('184.8294'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 144,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7995'),
#   'close_price': Decimal('184.8144'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8294'),
#   'close_price': Decimal('184.7995'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 140,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7995'),
#   'close_price': Decimal('184.7995'),
#   'high_price': Decimal('184.8294'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 384,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8393'),
#   'close_price': Decimal('184.8144'),
#   'high_price': Decimal('184.8493'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 345,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8294'),
#   'close_price': Decimal('184.8393'),
#   'high_price': Decimal('184.8493'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 1209,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8593'),
#   'close_price': Decimal('184.8493'),
#   'high_price': Decimal('184.8593'),
#   'low_price': Decimal('184.8244'),
#   'number_of_trades': None,
#   'volume': 1371,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8393'),
#   'close_price': Decimal('184.8593'),
#   'high_price': Decimal('184.8692'),
#   'low_price': Decimal('184.8194'),
#   'number_of_trades': None,
#   'volume': 150,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7995'),
#   'close_price': Decimal('184.8692'),
#   'high_price': Decimal('184.8692'),
#   'low_price': Decimal('184.7995'),
#   'number_of_trades': None,
#   'volume': 156,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8692'),
#   'close_price': Decimal('184.8095'),
#   'high_price': Decimal('184.8692'),
#   'low_price': Decimal('184.6999'),
#   'number_of_trades': None,
#   'volume': 98,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8095'),
#   'close_price': Decimal('184.8294'),
#   'high_price': Decimal('184.8792'),
#   'low_price': Decimal('184.7397'),
#   'number_of_trades': None,
#   'volume': 176,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7895'),
#   'close_price': Decimal('184.8493'),
#   'high_price': Decimal('184.8792'),
#   'low_price': Decimal('184.7895'),
#   'number_of_trades': None,
#   'volume': 422,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7497'),
#   'close_price': Decimal('184.7497'),
#   'high_price': Decimal('184.8493'),
#   'low_price': Decimal('184.6700'),
#   'number_of_trades': None,
#   'volume': 369,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7796'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.8194'),
#   'low_price': Decimal('184.6501'),
#   'number_of_trades': None,
#   'volume': 1581,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8393'),
#   'close_price': Decimal('184.7796'),
#   'high_price': Decimal('184.8393'),
#   'low_price': Decimal('184.7596'),
#   'number_of_trades': None,
#   'volume': 322,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7995'),
#   'close_price': Decimal('184.7596'),
#   'high_price': Decimal('184.7995'),
#   'low_price': Decimal('184.7397'),
#   'number_of_trades': None,
#   'volume': 133,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8095'),
#   'close_price': Decimal('184.7497'),
#   'high_price': Decimal('184.8692'),
#   'low_price': Decimal('184.6999'),
#   'number_of_trades': None,
#   'volume': 2590,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6899'),
#   'close_price': Decimal('184.8792'),
#   'high_price': Decimal('184.8792'),
#   'low_price': Decimal('184.6301'),
#   'number_of_trades': None,
#   'volume': 2754,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6202'),
#   'high_price': Decimal('184.7098'),
#   'low_price': Decimal('184.6202'),
#   'number_of_trades': None,
#   'volume': 406,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.6999'),
#   'low_price': Decimal('184.6202'),
#   'number_of_trades': None,
#   'volume': 22,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.6999'),
#   'low_price': Decimal('184.6202'),
#   'number_of_trades': None,
#   'volume': 170,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6994'),
#   'close_price': Decimal('184.6501'),
#   'high_price': Decimal('184.6999'),
#   'low_price': Decimal('184.6002'),
#   'number_of_trades': None,
#   'volume': 380,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7497'),
#   'close_price': Decimal('184.6501'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 376,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7397'),
#   'close_price': Decimal('184.7497'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6002'),
#   'number_of_trades': None,
#   'volume': 625,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7497'),
#   'close_price': Decimal('184.6202'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 30,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7497'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.5604'),
#   'number_of_trades': None,
#   'volume': 153,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5504'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.7098'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 1349,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7397'),
#   'close_price': Decimal('184.7397'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 111,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6002'),
#   'close_price': Decimal('184.5604'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.5604'),
#   'number_of_trades': None,
#   'volume': 514,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 467,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6152'),
#   'close_price': Decimal('184.5504'),
#   'high_price': Decimal('184.6501'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 416,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6401'),
#   'close_price': Decimal('184.6152'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 39,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5504'),
#   'close_price': Decimal('184.5604'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.4309'),
#   'number_of_trades': None,
#   'volume': 54,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 19, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5604'),
#   'close_price': Decimal('184.6700'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.5405'),
#   'number_of_trades': None,
#   'volume': 429,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 18, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6501'),
#   'close_price': Decimal('184.5355'),
#   'high_price': Decimal('184.6899'),
#   'low_price': Decimal('184.5106'),
#   'number_of_trades': None,
#   'volume': 37,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 17, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6600'),
#   'close_price': Decimal('184.6501'),
#   'high_price': Decimal('184.6999'),
#   'low_price': Decimal('184.5006'),
#   'number_of_trades': None,
#   'volume': 2418,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 16, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6999'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.7397'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 989,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6899'),
#   'close_price': Decimal('184.7397'),
#   'high_price': Decimal('184.7397'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 984,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 14, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.6899'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 692,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 13, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.7397'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6999'),
#   'number_of_trades': None,
#   'volume': 298,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 12, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6999'),
#   'number_of_trades': None,
#   'volume': 240,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 11, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7098'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 243,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7049'),
#   'close_price': Decimal('184.6899'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 499,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 9, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6999'),
#   'close_price': Decimal('184.7049'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 216,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 8, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6899'),
#   'close_price': Decimal('184.6899'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6899'),
#   'number_of_trades': None,
#   'volume': 331,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 7, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.6899'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6401'),
#   'number_of_trades': None,
#   'volume': 956,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 6, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6700'),
#   'close_price': Decimal('184.7198'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.6700'),
#   'number_of_trades': None,
#   'volume': 774,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 46,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 4, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7298'),
#   'close_price': Decimal('184.6700'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 67,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 3, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7198'),
#   'close_price': Decimal('184.6650'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.6501'),
#   'number_of_trades': None,
#   'volume': 309,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 2, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7098'),
#   'close_price': Decimal('184.6999'),
#   'high_price': Decimal('184.7198'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 258,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 1, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6799'),
#   'close_price': Decimal('184.5903'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.5206'),
#   'number_of_trades': None,
#   'volume': 2130,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6700'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.7098'),
#   'low_price': Decimal('184.4309'),
#   'number_of_trades': None,
#   'volume': 1572,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6700'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 1175,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6501'),
#   'close_price': Decimal('184.6700'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.6337'),
#   'number_of_trades': None,
#   'volume': 272,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7298'),
#   'close_price': Decimal('184.6700'),
#   'high_price': Decimal('184.7397'),
#   'low_price': Decimal('184.6700'),
#   'number_of_trades': None,
#   'volume': 1817,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 56, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7298'),
#   'close_price': Decimal('184.7298'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 348,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6799'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.7298'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 230,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 54, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.7497'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 1901,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 53, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6401'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 3116,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 52, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6799'),
#   'close_price': Decimal('184.6501'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6401'),
#   'number_of_trades': None,
#   'volume': 42,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 51, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6600'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6202'),
#   'number_of_trades': None,
#   'volume': 144,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.6401'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 329,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 49, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 170,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 48, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6202'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 3298,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 47, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5893'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.5455'),
#   'number_of_trades': None,
#   'volume': 1077,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 46, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5803'),
#   'close_price': Decimal('184.6002'),
#   'high_price': Decimal('184.6102'),
#   'low_price': Decimal('184.4508'),
#   'number_of_trades': None,
#   'volume': 534,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5604'),
#   'close_price': Decimal('184.5654'),
#   'high_price': Decimal('184.6202'),
#   'low_price': Decimal('184.3412'),
#   'number_of_trades': None,
#   'volume': 737,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 44, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5803'),
#   'close_price': Decimal('184.5604'),
#   'high_price': Decimal('184.6002'),
#   'low_price': Decimal('184.5504'),
#   'number_of_trades': None,
#   'volume': 149,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 43, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5405'),
#   'close_price': Decimal('184.5803'),
#   'high_price': Decimal('184.5803'),
#   'low_price': Decimal('184.5255'),
#   'number_of_trades': None,
#   'volume': 7,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 42, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5953'),
#   'close_price': Decimal('184.5255'),
#   'high_price': Decimal('184.6002'),
#   'low_price': Decimal('184.4508'),
#   'number_of_trades': None,
#   'volume': 130,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 41, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6002'),
#   'close_price': Decimal('184.6002'),
#   'high_price': Decimal('184.6202'),
#   'low_price': Decimal('184.6002'),
#   'number_of_trades': None,
#   'volume': 443,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6202'),
#   'close_price': Decimal('184.6052'),
#   'high_price': Decimal('184.6202'),
#   'low_price': Decimal('184.6002'),
#   'number_of_trades': None,
#   'volume': 384,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 39, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6351'),
#   'close_price': Decimal('184.6102'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6102'),
#   'number_of_trades': None,
#   'volume': 102,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 38, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5903'),
#   'close_price': Decimal('184.6202'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.5903'),
#   'number_of_trades': None,
#   'volume': 40,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 37, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6351'),
#   'close_price': Decimal('184.6401'),
#   'high_price': Decimal('184.6799'),
#   'low_price': Decimal('184.6002'),
#   'number_of_trades': None,
#   'volume': 62,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 36, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6501'),
#   'close_price': Decimal('184.6695'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.6351'),
#   'number_of_trades': None,
#   'volume': 179,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6351'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.6899'),
#   'low_price': Decimal('184.5803'),
#   'number_of_trades': None,
#   'volume': 43,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 34, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6102'),
#   'close_price': Decimal('184.6799'),
#   'high_price': Decimal('184.6999'),
#   'low_price': Decimal('184.5803'),
#   'number_of_trades': None,
#   'volume': 216,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 33, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5853'),
#   'close_price': Decimal('184.6401'),
#   'high_price': Decimal('184.6700'),
#   'low_price': Decimal('184.5803'),
#   'number_of_trades': None,
#   'volume': 1595,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 32, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5903'),
#   'close_price': Decimal('184.5803'),
#   'high_price': Decimal('184.5903'),
#   'low_price': Decimal('184.5803'),
#   'number_of_trades': None,
#   'volume': 178,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 31, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5504'),
#   'close_price': Decimal('184.5853'),
#   'high_price': Decimal('184.5903'),
#   'low_price': Decimal('184.5156'),
#   'number_of_trades': None,
#   'volume': 878,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5106'),
#   'close_price': Decimal('184.5803'),
#   'high_price': Decimal('184.5903'),
#   'low_price': Decimal('184.4508'),
#   'number_of_trades': None,
#   'volume': 605,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 29, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4508'),
#   'close_price': Decimal('184.4409'),
#   'high_price': Decimal('184.5006'),
#   'low_price': Decimal('184.4110'),
#   'number_of_trades': None,
#   'volume': 1310,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 28, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4675'),
#   'close_price': Decimal('184.4409'),
#   'high_price': Decimal('184.4707'),
#   'low_price': Decimal('184.4110'),
#   'number_of_trades': None,
#   'volume': 393,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 27, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4309'),
#   'close_price': Decimal('184.4409'),
#   'high_price': Decimal('184.4409'),
#   'low_price': Decimal('184.3612'),
#   'number_of_trades': None,
#   'volume': 134,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 26, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4608'),
#   'close_price': Decimal('184.4110'),
#   'high_price': Decimal('184.4707'),
#   'low_price': Decimal('184.4110'),
#   'number_of_trades': None,
#   'volume': 236,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4159'),
#   'close_price': Decimal('184.4110'),
#   'high_price': Decimal('184.4533'),
#   'low_price': Decimal('184.4110'),
#   'number_of_trades': None,
#   'volume': 61,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 24, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4110'),
#   'close_price': Decimal('184.3612'),
#   'high_price': Decimal('184.4707'),
#   'low_price': Decimal('184.3512'),
#   'number_of_trades': None,
#   'volume': 374,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 23, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3512'),
#   'close_price': Decimal('184.4209'),
#   'high_price': Decimal('184.4707'),
#   'low_price': Decimal('184.3512'),
#   'number_of_trades': None,
#   'volume': 78,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 22, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3512'),
#   'close_price': Decimal('184.4010'),
#   'high_price': Decimal('184.4707'),
#   'low_price': Decimal('184.3512'),
#   'number_of_trades': None,
#   'volume': 42,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 21, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4807'),
#   'close_price': Decimal('184.4110'),
#   'high_price': Decimal('184.4807'),
#   'low_price': Decimal('183.7036'),
#   'number_of_trades': None,
#   'volume': 1222,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 20, tzinfo=<UTC>)}]

# %%
dataset_b
# Out:
# [{'open_price': 185.34,
#   'close_price': 185.1,
#   'high_price': 185.34,
#   'low_price': 184.97,
#   'number_of_trades': 266,
#   'volume': 7053,
#   'volume_weighted_average': 185.0455,
#   'time': datetime.datetime(2024, 1, 9, 9, 0, tzinfo=<UTC>)},
#  {'open_price': 185.07,
#   'close_price': 184.95,
#   'high_price': 185.07,
#   'low_price': 184.92,
#   'number_of_trades': 165,
#   'volume': 7461,
#   'volume_weighted_average': 184.9948,
#   'time': datetime.datetime(2024, 1, 9, 9, 5, tzinfo=<UTC>)},
#  {'open_price': 184.95,
#   'close_price': 185,
#   'high_price': 185,
#   'low_price': 184.86,
#   'number_of_trades': 68,
#   'volume': 5547,
#   'volume_weighted_average': 184.935,
#   'time': datetime.datetime(2024, 1, 9, 9, 10, tzinfo=<UTC>)},
#  {'open_price': 184.93,
#   'close_price': 184.99,
#   'high_price': 184.99,
#   'low_price': 184.85,
#   'number_of_trades': 86,
#   'volume': 5081,
#   'volume_weighted_average': 184.9384,
#   'time': datetime.datetime(2024, 1, 9, 9, 15, tzinfo=<UTC>)},
#  {'open_price': 184.91,
#   'close_price': 184.9,
#   'high_price': 184.91,
#   'low_price': 184.9,
#   'number_of_trades': 62,
#   'volume': 2585,
#   'volume_weighted_average': 184.9148,
#   'time': datetime.datetime(2024, 1, 9, 9, 20, tzinfo=<UTC>)},
#  {'open_price': 185,
#   'close_price': 184.96,
#   'high_price': 185,
#   'low_price': 184.96,
#   'number_of_trades': 52,
#   'volume': 3252,
#   'volume_weighted_average': 184.9728,
#   'time': datetime.datetime(2024, 1, 9, 9, 30, tzinfo=<UTC>)},
#  {'open_price': 185.02,
#   'close_price': 185.03,
#   'high_price': 185.03,
#   'low_price': 185.02,
#   'number_of_trades': 34,
#   'volume': 1206,
#   'volume_weighted_average': 185.0229,
#   'time': datetime.datetime(2024, 1, 9, 9, 35, tzinfo=<UTC>)},
#  {'open_price': 185.04,
#   'close_price': 185.04,
#   'high_price': 185.04,
#   'low_price': 185.04,
#   'number_of_trades': 9,
#   'volume': 816,
#   'volume_weighted_average': 185.0433,
#   'time': datetime.datetime(2024, 1, 9, 9, 40, tzinfo=<UTC>)},
#  {'open_price': 185.14,
#   'close_price': 185.09,
#   'high_price': 185.14,
#   'low_price': 185.09,
#   'number_of_trades': 28,
#   'volume': 1700,
#   'volume_weighted_average': 185.0979,
#   'time': datetime.datetime(2024, 1, 9, 9, 55, tzinfo=<UTC>)},
#  {'open_price': 185.1,
#   'close_price': 185.05,
#   'high_price': 185.1,
#   'low_price': 185.05,
#   'number_of_trades': 50,
#   'volume': 3078,
#   'volume_weighted_average': 185.0778,
#   'time': datetime.datetime(2024, 1, 9, 10, 0, tzinfo=<UTC>)},
#  {'open_price': 185.01,
#   'close_price': 185,
#   'high_price': 185.01,
#   'low_price': 185,
#   'number_of_trades': 67,
#   'volume': 3169,
#   'volume_weighted_average': 185.0022,
#   'time': datetime.datetime(2024, 1, 9, 10, 5, tzinfo=<UTC>)},
#  {'open_price': 185.05,
#   'close_price': 184.98,
#   'high_price': 185.05,
#   'low_price': 184.98,
#   'number_of_trades': 107,
#   'volume': 4397,
#   'volume_weighted_average': 185.0382,
#   'time': datetime.datetime(2024, 1, 9, 10, 10, tzinfo=<UTC>)},
#  {'open_price': 185.01,
#   'close_price': 185.02,
#   'high_price': 185.02,
#   'low_price': 185.01,
#   'number_of_trades': 13,
#   'volume': 441,
#   'volume_weighted_average': 185.0183,
#   'time': datetime.datetime(2024, 1, 9, 10, 15, tzinfo=<UTC>)},
#  {'open_price': 185.1,
#   'close_price': 185.1,
#   'high_price': 185.1,
#   'low_price': 185.1,
#   'number_of_trades': 7,
#   'volume': 134,
#   'volume_weighted_average': 185.0989,
#   'time': datetime.datetime(2024, 1, 9, 10, 25, tzinfo=<UTC>)},
#  {'open_price': 185.05,
#   'close_price': 185.02,
#   'high_price': 185.05,
#   'low_price': 185.02,
#   'number_of_trades': 33,
#   'volume': 808,
#   'volume_weighted_average': 185.0378,
#   'time': datetime.datetime(2024, 1, 9, 10, 30, tzinfo=<UTC>)},
#  {'open_price': 185.1,
#   'close_price': 185.1,
#   'high_price': 185.1,
#   'low_price': 185.1,
#   'number_of_trades': 12,
#   'volume': 488,
#   'volume_weighted_average': 185.0909,
#   'time': datetime.datetime(2024, 1, 9, 10, 35, tzinfo=<UTC>)},
#  {'open_price': 185.02,
#   'close_price': 185.01,
#   'high_price': 185.02,
#   'low_price': 185.01,
#   'number_of_trades': 21,
#   'volume': 673,
#   'volume_weighted_average': 185.0163,
#   'time': datetime.datetime(2024, 1, 9, 10, 45, tzinfo=<UTC>)},
#  {'open_price': 185.02,
#   'close_price': 185.01,
#   'high_price': 185.02,
#   'low_price': 185.01,
#   'number_of_trades': 28,
#   'volume': 776,
#   'volume_weighted_average': 185.0119,
#   'time': datetime.datetime(2024, 1, 9, 10, 55, tzinfo=<UTC>)},
#  {'open_price': 185,
#   'close_price': 185,
#   'high_price': 185,
#   'low_price': 185,
#   'number_of_trades': 8,
#   'volume': 249,
#   'volume_weighted_average': 185.0011,
#   'time': datetime.datetime(2024, 1, 9, 11, 0, tzinfo=<UTC>)},
#  {'open_price': 184.95,
#   'close_price': 184.95,
#   'high_price': 184.95,
#   'low_price': 184.95,
#   'number_of_trades': 15,
#   'volume': 268,
#   'volume_weighted_average': 184.9562,
#   'time': datetime.datetime(2024, 1, 9, 11, 5, tzinfo=<UTC>)},
#  {'open_price': 184.9,
#   'close_price': 184.94,
#   'high_price': 184.94,
#   'low_price': 184.9,
#   'number_of_trades': 81,
#   'volume': 1455,
#   'volume_weighted_average': 184.9083,
#   'time': datetime.datetime(2024, 1, 9, 11, 10, tzinfo=<UTC>)},
#  {'open_price': 184.86,
#   'close_price': 184.81,
#   'high_price': 184.86,
#   'low_price': 184.8,
#   'number_of_trades': 110,
#   'volume': 2366,
#   'volume_weighted_average': 184.8274,
#   'time': datetime.datetime(2024, 1, 9, 11, 25, tzinfo=<UTC>)},
#  {'open_price': 184.81,
#   'close_price': 184.86,
#   'high_price': 184.86,
#   'low_price': 184.81,
#   'number_of_trades': 34,
#   'volume': 1376,
#   'volume_weighted_average': 184.8464,
#   'time': datetime.datetime(2024, 1, 9, 11, 30, tzinfo=<UTC>)},
#  {'open_price': 184.82,
#   'close_price': 184.82,
#   'high_price': 184.82,
#   'low_price': 184.82,
#   'number_of_trades': 11,
#   'volume': 349,
#   'volume_weighted_average': 184.8421,
#   'time': datetime.datetime(2024, 1, 9, 11, 35, tzinfo=<UTC>)},
#  {'open_price': 184.81,
#   'close_price': 184.81,
#   'high_price': 184.81,
#   'low_price': 184.81,
#   'number_of_trades': 33,
#   'volume': 908,
#   'volume_weighted_average': 184.8094,
#   'time': datetime.datetime(2024, 1, 9, 11, 40, tzinfo=<UTC>)},
#  {'open_price': 184.81,
#   'close_price': 184.84,
#   'high_price': 184.84,
#   'low_price': 184.79,
#   'number_of_trades': 89,
#   'volume': 3115,
#   'volume_weighted_average': 184.8135,
#   'time': datetime.datetime(2024, 1, 9, 11, 45, tzinfo=<UTC>)},
#  {'open_price': 184.71,
#   'close_price': 184.72,
#   'high_price': 184.72,
#   'low_price': 184.71,
#   'number_of_trades': 25,
#   'volume': 817,
#   'volume_weighted_average': 184.7289,
#   'time': datetime.datetime(2024, 1, 9, 11, 55, tzinfo=<UTC>)},
#  {'open_price': 184.76,
#   'close_price': 184.39,
#   'high_price': 184.8,
#   'low_price': 184.39,
#   'number_of_trades': 417,
#   'volume': 16873,
#   'volume_weighted_average': 184.5836,
#   'time': datetime.datetime(2024, 1, 9, 12, 0, tzinfo=<UTC>)},
#  {'open_price': 184.49,
#   'close_price': 184.45,
#   'high_price': 184.49,
#   'low_price': 184.4,
#   'number_of_trades': 129,
#   'volume': 7863,
#   'volume_weighted_average': 184.4468,
#   'time': datetime.datetime(2024, 1, 9, 12, 5, tzinfo=<UTC>)},
#  {'open_price': 184.5,
#   'close_price': 184.48,
#   'high_price': 184.55,
#   'low_price': 184.46,
#   'number_of_trades': 135,
#   'volume': 6107,
#   'volume_weighted_average': 184.5137,
#   'time': datetime.datetime(2024, 1, 9, 12, 10, tzinfo=<UTC>)},
#  {'open_price': 184.54,
#   'close_price': 184.55,
#   'high_price': 184.55,
#   'low_price': 184.54,
#   'number_of_trades': 100,
#   'volume': 7545,
#   'volume_weighted_average': 184.5499,
#   'time': datetime.datetime(2024, 1, 9, 12, 15, tzinfo=<UTC>)},
#  {'open_price': 184.49,
#   'close_price': 184.41,
#   'high_price': 184.5,
#   'low_price': 184.41,
#   'number_of_trades': 127,
#   'volume': 3867,
#   'volume_weighted_average': 184.4633,
#   'time': datetime.datetime(2024, 1, 9, 12, 20, tzinfo=<UTC>)},
#  {'open_price': 184.44,
#   'close_price': 184.31,
#   'high_price': 184.44,
#   'low_price': 184.3,
#   'number_of_trades': 171,
#   'volume': 7115,
#   'volume_weighted_average': 184.3697,
#   'time': datetime.datetime(2024, 1, 9, 12, 25, tzinfo=<UTC>)},
#  {'open_price': 184.31,
#   'close_price': 184.46,
#   'high_price': 184.46,
#   'low_price': 184.16,
#   'number_of_trades': 203,
#   'volume': 11174,
#   'volume_weighted_average': 184.3289,
#   'time': datetime.datetime(2024, 1, 9, 12, 30, tzinfo=<UTC>)},
#  {'open_price': 184.48,
#   'close_price': 184.49,
#   'high_price': 184.53,
#   'low_price': 184.46,
#   'number_of_trades': 76,
#   'volume': 3523,
#   'volume_weighted_average': 184.4968,
#   'time': datetime.datetime(2024, 1, 9, 12, 35, tzinfo=<UTC>)},
#  {'open_price': 184.52,
#   'close_price': 184.52,
#   'high_price': 184.52,
#   'low_price': 184.47,
#   'number_of_trades': 96,
#   'volume': 2949,
#   'volume_weighted_average': 184.4957,
#   'time': datetime.datetime(2024, 1, 9, 12, 40, tzinfo=<UTC>)},
#  {'open_price': 184.5,
#   'close_price': 184.59,
#   'high_price': 184.61,
#   'low_price': 184.49,
#   'number_of_trades': 168,
#   'volume': 4699,
#   'volume_weighted_average': 184.5284,
#   'time': datetime.datetime(2024, 1, 9, 12, 45, tzinfo=<UTC>)},
#  {'open_price': 184.52,
#   'close_price': 184.6,
#   'high_price': 184.66,
#   'low_price': 184.48,
#   'number_of_trades': 142,
#   'volume': 7053,
#   'volume_weighted_average': 184.5801,
#   'time': datetime.datetime(2024, 1, 9, 12, 50, tzinfo=<UTC>)},
#  {'open_price': 184.76,
#   'close_price': 184.55,
#   'high_price': 184.76,
#   'low_price': 184.55,
#   'number_of_trades': 165,
#   'volume': 6589,
#   'volume_weighted_average': 184.6277,
#   'time': datetime.datetime(2024, 1, 9, 12, 55, tzinfo=<UTC>)},
#  {'open_price': 184.8,
#   'close_price': 184.5,
#   'high_price': 186.43,
#   'low_price': 184.24,
#   'number_of_trades': 3258,
#   'volume': 323211,
#   'volume_weighted_average': 185.4836,
#   'time': datetime.datetime(2024, 1, 9, 13, 0, tzinfo=<UTC>)},
#  {'open_price': 184.5,
#   'close_price': 184.4,
#   'high_price': 184.5,
#   'low_price': 184.3,
#   'number_of_trades': 380,
#   'volume': 20884,
#   'volume_weighted_average': 184.4256,
#   'time': datetime.datetime(2024, 1, 9, 13, 5, tzinfo=<UTC>)},
#  {'open_price': 184.3551,
#   'close_price': 184.45,
#   'high_price': 184.4764,
#   'low_price': 184.3551,
#   'number_of_trades': 109,
#   'volume': 2708,
#   'volume_weighted_average': 184.4366,
#   'time': datetime.datetime(2024, 1, 9, 13, 10, tzinfo=<UTC>)},
#  {'open_price': 184.4,
#   'close_price': 184.3,
#   'high_price': 184.45,
#   'low_price': 184.25,
#   'number_of_trades': 337,
#   'volume': 7320,
#   'volume_weighted_average': 184.3312,
#   'time': datetime.datetime(2024, 1, 9, 13, 15, tzinfo=<UTC>)},
#  {'open_price': 184.3,
#   'close_price': 184.3,
#   'high_price': 184.39,
#   'low_price': 184.28,
#   'number_of_trades': 248,
#   'volume': 14490,
#   'volume_weighted_average': 184.3373,
#   'time': datetime.datetime(2024, 1, 9, 13, 20, tzinfo=<UTC>)},
#  {'open_price': 184.31,
#   'close_price': 184.31,
#   'high_price': 184.3899,
#   'low_price': 184.31,
#   'number_of_trades': 230,
#   'volume': 8178,
#   'volume_weighted_average': 184.3474,
#   'time': datetime.datetime(2024, 1, 9, 13, 25, tzinfo=<UTC>)},
#  {'open_price': 184.32,
#   'close_price': 184.13,
#   'high_price': 184.39,
#   'low_price': 184.13,
#   'number_of_trades': 464,
#   'volume': 25297,
#   'volume_weighted_average': 184.2277,
#   'time': datetime.datetime(2024, 1, 9, 13, 30, tzinfo=<UTC>)},
#  {'open_price': 184.1701,
#   'close_price': 184.01,
#   'high_price': 184.1701,
#   'low_price': 183.97,
#   'number_of_trades': 849,
#   'volume': 37577,
#   'volume_weighted_average': 184.0603,
#   'time': datetime.datetime(2024, 1, 9, 13, 35, tzinfo=<UTC>)},
#  {'open_price': 184.05,
#   'close_price': 183.83,
#   'high_price': 184.05,
#   'low_price': 183.83,
#   'number_of_trades': 494,
#   'volume': 20030,
#   'volume_weighted_average': 183.9148,
#   'time': datetime.datetime(2024, 1, 9, 13, 40, tzinfo=<UTC>)},
#  {'open_price': 183.81,
#   'close_price': 183.93,
#   'high_price': 183.95,
#   'low_price': 183.7,
#   'number_of_trades': 533,
#   'volume': 19696,
#   'volume_weighted_average': 183.82,
#   'time': datetime.datetime(2024, 1, 9, 13, 45, tzinfo=<UTC>)},
#  {'open_price': 183.9799,
#   'close_price': 183.84,
#   'high_price': 184,
#   'low_price': 183.79,
#   'number_of_trades': 396,
#   'volume': 12062,
#   'volume_weighted_average': 183.8772,
#   'time': datetime.datetime(2024, 1, 9, 13, 50, tzinfo=<UTC>)},
#  {'open_price': 183.84,
#   'close_price': 183.835,
#   'high_price': 183.86,
#   'low_price': 183.76,
#   'number_of_trades': 416,
#   'volume': 12575,
#   'volume_weighted_average': 183.8248,
#   'time': datetime.datetime(2024, 1, 9, 13, 55, tzinfo=<UTC>)},
#  {'open_price': 183.87,
#   'close_price': 183.93,
#   'high_price': 183.93,
#   'low_price': 183.8029,
#   'number_of_trades': 330,
#   'volume': 13027,
#   'volume_weighted_average': 183.8977,
#   'time': datetime.datetime(2024, 1, 9, 14, 0, tzinfo=<UTC>)},
#  {'open_price': 183.93,
#   'close_price': 183.94,
#   'high_price': 184,
#   'low_price': 183.83,
#   'number_of_trades': 609,
#   'volume': 19614,
#   'volume_weighted_average': 183.9147,
#   'time': datetime.datetime(2024, 1, 9, 14, 5, tzinfo=<UTC>)},
#  {'open_price': 183.94,
#   'close_price': 183.9996,
#   'high_price': 184,
#   'low_price': 183.92,
#   'number_of_trades': 367,
#   'volume': 10019,
#   'volume_weighted_average': 183.9713,
#   'time': datetime.datetime(2024, 1, 9, 14, 10, tzinfo=<UTC>)},
#  {'open_price': 184,
#   'close_price': 183.9,
#   'high_price': 184.05,
#   'low_price': 183.82,
#   'number_of_trades': 526,
#   'volume': 15823,
#   'volume_weighted_average': 183.9179,
#   'time': datetime.datetime(2024, 1, 9, 14, 15, tzinfo=<UTC>)},
#  {'open_price': 183.83,
#   'close_price': 183.84,
#   'high_price': 183.88,
#   'low_price': 183.75,
#   'number_of_trades': 575,
#   'volume': 18346,
#   'volume_weighted_average': 183.8107,
#   'time': datetime.datetime(2024, 1, 9, 14, 20, tzinfo=<UTC>)},
#  {'open_price': 183.85,
#   'close_price': 184.03,
#   'high_price': 184.1,
#   'low_price': 183.85,
#   'number_of_trades': 767,
#   'volume': 39844,
#   'volume_weighted_average': 184.0093,
#   'time': datetime.datetime(2024, 1, 9, 14, 25, tzinfo=<UTC>)},
#  {'open_price': 183.92,
#   'close_price': 183.86,
#   'high_price': 184.23,
#   'low_price': 183.55,
#   'number_of_trades': 22337,
#   'volume': 2048681.0,
#   'volume_weighted_average': 183.8826,
#   'time': datetime.datetime(2024, 1, 9, 14, 30, tzinfo=<UTC>)},
#  {'open_price': 183.8536,
#   'close_price': 183.25,
#   'high_price': 183.94,
#   'low_price': 183.25,
#   'number_of_trades': 13618,
#   'volume': 996035,
#   'volume_weighted_average': 183.6564,
#   'time': datetime.datetime(2024, 1, 9, 14, 35, tzinfo=<UTC>)},
#  {'open_price': 183.25,
#   'close_price': 182.91,
#   'high_price': 183.4278,
#   'low_price': 182.825,
#   'number_of_trades': 14138,
#   'volume': 1163929.0,
#   'volume_weighted_average': 183.1075,
#   'time': datetime.datetime(2024, 1, 9, 14, 40, tzinfo=<UTC>)},
#  {'open_price': 182.9,
#   'close_price': 183.015,
#   'high_price': 183.03,
#   'low_price': 182.73,
#   'number_of_trades': 11553,
#   'volume': 927378,
#   'volume_weighted_average': 182.8639,
#   'time': datetime.datetime(2024, 1, 9, 14, 45, tzinfo=<UTC>)},
#  {'open_price': 183.01,
#   'close_price': 183.0024,
#   'high_price': 183.22,
#   'low_price': 182.91,
#   'number_of_trades': 9590,
#   'volume': 645167,
#   'volume_weighted_average': 183.0845,
#   'time': datetime.datetime(2024, 1, 9, 14, 50, tzinfo=<UTC>)},
#  {'open_price': 183,
#   'close_price': 183.27,
#   'high_price': 183.295,
#   'low_price': 182.9,
#   'number_of_trades': 7445,
#   'volume': 559792,
#   'volume_weighted_average': 183.141,
#   'time': datetime.datetime(2024, 1, 9, 14, 55, tzinfo=<UTC>)},
#  {'open_price': 183.255,
#   'close_price': 183.0599,
#   'high_price': 183.3,
#   'low_price': 183.0425,
#   'number_of_trades': 7952,
#   'volume': 525510,
#   'volume_weighted_average': 183.1783,
#   'time': datetime.datetime(2024, 1, 9, 15, 0, tzinfo=<UTC>)},
#  {'open_price': 183.06,
#   'close_price': 183.62,
#   'high_price': 183.63,
#   'low_price': 182.97,
#   'number_of_trades': 20575,
#   'volume': 770208,
#   'volume_weighted_average': 183.3195,
#   'time': datetime.datetime(2024, 1, 9, 15, 5, tzinfo=<UTC>)},
#  {'open_price': 183.625,
#   'close_price': 183.93,
#   'high_price': 183.94,
#   'low_price': 183.62,
#   'number_of_trades': 21718,
#   'volume': 626962,
#   'volume_weighted_average': 183.7933,
#   'time': datetime.datetime(2024, 1, 9, 15, 10, tzinfo=<UTC>)},
#  {'open_price': 183.9213,
#   'close_price': 183.8424,
#   'high_price': 183.98,
#   'low_price': 183.6601,
#   'number_of_trades': 23632,
#   'volume': 626703,
#   'volume_weighted_average': 183.8668,
#   'time': datetime.datetime(2024, 1, 9, 15, 15, tzinfo=<UTC>)},
#  {'open_price': 183.84,
#   'close_price': 183.76,
#   'high_price': 183.91,
#   'low_price': 183.73,
#   'number_of_trades': 20187,
#   'volume': 383305,
#   'volume_weighted_average': 183.8258,
#   'time': datetime.datetime(2024, 1, 9, 15, 20, tzinfo=<UTC>)},
#  {'open_price': 183.7487,
#   'close_price': 183.525,
#   'high_price': 183.7487,
#   'low_price': 183.425,
#   'number_of_trades': 19925,
#   'volume': 459332,
#   'volume_weighted_average': 183.5571,
#   'time': datetime.datetime(2024, 1, 9, 15, 25, tzinfo=<UTC>)},
#  {'open_price': 183.53,
#   'close_price': 183.4939,
#   'high_price': 183.53,
#   'low_price': 183.21,
#   'number_of_trades': 22402,
#   'volume': 495961,
#   'volume_weighted_average': 183.4034,
#   'time': datetime.datetime(2024, 1, 9, 15, 30, tzinfo=<UTC>)},
#  {'open_price': 183.49,
#   'close_price': 183.735,
#   'high_price': 183.7385,
#   'low_price': 183.4555,
#   'number_of_trades': 18579,
#   'volume': 395719,
#   'volume_weighted_average': 183.6093,
#   'time': datetime.datetime(2024, 1, 9, 15, 35, tzinfo=<UTC>)},
#  {'open_price': 183.735,
#   'close_price': 183.6103,
#   'high_price': 183.74,
#   'low_price': 183.585,
#   'number_of_trades': 13421,
#   'volume': 277647,
#   'volume_weighted_average': 183.6637,
#   'time': datetime.datetime(2024, 1, 9, 15, 40, tzinfo=<UTC>)},
#  {'open_price': 183.61,
#   'close_price': 183.77,
#   'high_price': 183.78,
#   'low_price': 183.5989,
#   'number_of_trades': 4442,
#   'volume': 328430,
#   'volume_weighted_average': 183.7145,
#   'time': datetime.datetime(2024, 1, 9, 15, 45, tzinfo=<UTC>)},
#  {'open_price': 183.77,
#   'close_price': 183.6,
#   'high_price': 183.81,
#   'low_price': 183.52,
#   'number_of_trades': 4762,
#   'volume': 340848,
#   'volume_weighted_average': 183.7056,
#   'time': datetime.datetime(2024, 1, 9, 15, 50, tzinfo=<UTC>)},
#  {'open_price': 183.61,
#   'close_price': 183.4925,
#   'high_price': 183.75,
#   'low_price': 183.49,
#   'number_of_trades': 4481,
#   'volume': 338503,
#   'volume_weighted_average': 183.6179,
#   'time': datetime.datetime(2024, 1, 9, 15, 55, tzinfo=<UTC>)},
#  {'open_price': 183.49,
#   'close_price': 183.77,
#   'high_price': 183.8,
#   'low_price': 183.49,
#   'number_of_trades': 3935,
#   'volume': 296317,
#   'volume_weighted_average': 183.6588,
#   'time': datetime.datetime(2024, 1, 9, 16, 0, tzinfo=<UTC>)},
#  {'open_price': 183.77,
#   'close_price': 183.73,
#   'high_price': 183.8,
#   'low_price': 183.63,
#   'number_of_trades': 4199,
#   'volume': 328181,
#   'volume_weighted_average': 183.7201,
#   'time': datetime.datetime(2024, 1, 9, 16, 5, tzinfo=<UTC>)},
#  {'open_price': 183.725,
#   'close_price': 183.805,
#   'high_price': 183.83,
#   'low_price': 183.6926,
#   'number_of_trades': 3556,
#   'volume': 250508,
#   'volume_weighted_average': 183.7709,
#   'time': datetime.datetime(2024, 1, 9, 16, 10, tzinfo=<UTC>)},
#  {'open_price': 183.81,
#   'close_price': 184.075,
#   'high_price': 184.155,
#   'low_price': 183.79,
#   'number_of_trades': 5765,
#   'volume': 498356,
#   'volume_weighted_average': 184.0289,
#   'time': datetime.datetime(2024, 1, 9, 16, 15, tzinfo=<UTC>)},
#  {'open_price': 184.0769,
#   'close_price': 184.15,
#   'high_price': 184.15,
#   'low_price': 184.03,
#   'number_of_trades': 4172,
#   'volume': 286608,
#   'volume_weighted_average': 184.0849,
#   'time': datetime.datetime(2024, 1, 9, 16, 20, tzinfo=<UTC>)},
#  {'open_price': 184.146,
#   'close_price': 184.23,
#   'high_price': 184.26,
#   'low_price': 184.07,
#   'number_of_trades': 5962,
#   'volume': 765735,
#   'volume_weighted_average': 184.1676,
#   'time': datetime.datetime(2024, 1, 9, 16, 25, tzinfo=<UTC>)},
#  {'open_price': 184.23,
#   'close_price': 184.4276,
#   'high_price': 184.445,
#   'low_price': 184.15,
#   'number_of_trades': 6736,
#   'volume': 640123,
#   'volume_weighted_average': 184.3085,
#   'time': datetime.datetime(2024, 1, 9, 16, 30, tzinfo=<UTC>)},
#  {'open_price': 184.42,
#   'close_price': 184.315,
#   'high_price': 184.445,
#   'low_price': 184.26,
#   'number_of_trades': 4296,
#   'volume': 351391,
#   'volume_weighted_average': 184.3686,
#   'time': datetime.datetime(2024, 1, 9, 16, 35, tzinfo=<UTC>)},
#  {'open_price': 184.3114,
#   'close_price': 184.261,
#   'high_price': 184.33,
#   'low_price': 184.1601,
#   'number_of_trades': 4568,
#   'volume': 396657,
#   'volume_weighted_average': 184.1937,
#   'time': datetime.datetime(2024, 1, 9, 16, 40, tzinfo=<UTC>)},
#  {'open_price': 184.265,
#   'close_price': 184.39,
#   'high_price': 184.3978,
#   'low_price': 184.24,
#   'number_of_trades': 3209,
#   'volume': 246343,
#   'volume_weighted_average': 184.2903,
#   'time': datetime.datetime(2024, 1, 9, 16, 45, tzinfo=<UTC>)},
#  {'open_price': 184.395,
#   'close_price': 184.615,
#   'high_price': 184.625,
#   'low_price': 184.375,
#   'number_of_trades': 3822,
#   'volume': 322453,
#   'volume_weighted_average': 184.4969,
#   'time': datetime.datetime(2024, 1, 9, 16, 50, tzinfo=<UTC>)},
#  {'open_price': 184.61,
#   'close_price': 184.79,
#   'high_price': 184.8,
#   'low_price': 184.6,
#   'number_of_trades': 4302,
#   'volume': 350660,
#   'volume_weighted_average': 184.7016,
#   'time': datetime.datetime(2024, 1, 9, 16, 55, tzinfo=<UTC>)},
#  {'open_price': 184.795,
#   'close_price': 184.595,
#   'high_price': 184.83,
#   'low_price': 184.54,
#   'number_of_trades': 4607,
#   'volume': 390847,
#   'volume_weighted_average': 184.6285,
#   'time': datetime.datetime(2024, 1, 9, 17, 0, tzinfo=<UTC>)},
#  {'open_price': 184.595,
#   'close_price': 184.7723,
#   'high_price': 184.78,
#   'low_price': 184.59,
#   'number_of_trades': 3334,
#   'volume': 312317,
#   'volume_weighted_average': 184.7009,
#   'time': datetime.datetime(2024, 1, 9, 17, 5, tzinfo=<UTC>)},
#  {'open_price': 184.7745,
#   'close_price': 184.545,
#   'high_price': 184.78,
#   'low_price': 184.53,
#   'number_of_trades': 3457,
#   'volume': 243690,
#   'volume_weighted_average': 184.637,
#   'time': datetime.datetime(2024, 1, 9, 17, 10, tzinfo=<UTC>)},
#  {'open_price': 184.55,
#   'close_price': 184.4,
#   'high_price': 184.58,
#   'low_price': 184.38,
#   'number_of_trades': 3606,
#   'volume': 294516,
#   'volume_weighted_average': 184.47,
#   'time': datetime.datetime(2024, 1, 9, 17, 15, tzinfo=<UTC>)},
#  {'open_price': 184.39,
#   'close_price': 184.4018,
#   'high_price': 184.48,
#   'low_price': 184.375,
#   'number_of_trades': 2840,
#   'volume': 179917,
#   'volume_weighted_average': 184.4218,
#   'time': datetime.datetime(2024, 1, 9, 17, 20, tzinfo=<UTC>)},
#  {'open_price': 184.405,
#   'close_price': 184.44,
#   'high_price': 184.49,
#   'low_price': 184.405,
#   'number_of_trades': 2678,
#   'volume': 179499,
#   'volume_weighted_average': 184.4454,
#   'time': datetime.datetime(2024, 1, 9, 17, 25, tzinfo=<UTC>)},
#  {'open_price': 184.44,
#   'close_price': 184.435,
#   'high_price': 184.47,
#   'low_price': 184.39,
#   'number_of_trades': 3151,
#   'volume': 199644,
#   'volume_weighted_average': 184.4252,
#   'time': datetime.datetime(2024, 1, 9, 17, 30, tzinfo=<UTC>)},
#  {'open_price': 184.435,
#   'close_price': 184.44,
#   'high_price': 184.47,
#   'low_price': 184.39,
#   'number_of_trades': 3245,
#   'volume': 210242,
#   'volume_weighted_average': 184.4238,
#   'time': datetime.datetime(2024, 1, 9, 17, 35, tzinfo=<UTC>)},
#  {'open_price': 184.435,
#   'close_price': 184.585,
#   'high_price': 184.63,
#   'low_price': 184.435,
#   'number_of_trades': 2949,
#   'volume': 206279,
#   'volume_weighted_average': 184.5712,
#   'time': datetime.datetime(2024, 1, 9, 17, 40, tzinfo=<UTC>)},
#  {'open_price': 184.5809,
#   'close_price': 184.58,
#   'high_price': 184.61,
#   'low_price': 184.51,
#   'number_of_trades': 2747,
#   'volume': 172878,
#   'volume_weighted_average': 184.5625,
#   'time': datetime.datetime(2024, 1, 9, 17, 45, tzinfo=<UTC>)},
#  {'open_price': 184.585,
#   'close_price': 184.7737,
#   'high_price': 184.81,
#   'low_price': 184.57,
#   'number_of_trades': 3942,
#   'volume': 299236,
#   'volume_weighted_average': 184.691,
#   'time': datetime.datetime(2024, 1, 9, 17, 50, tzinfo=<UTC>)},
#  {'open_price': 184.7751,
#   'close_price': 184.72,
#   'high_price': 184.805,
#   'low_price': 184.68,
#   'number_of_trades': 2769,
#   'volume': 176567,
#   'volume_weighted_average': 184.7385,
#   'time': datetime.datetime(2024, 1, 9, 17, 55, tzinfo=<UTC>)},
#  {'open_price': 184.72,
#   'close_price': 184.82,
#   'high_price': 184.92,
#   'low_price': 184.7,
#   'number_of_trades': 4140,
#   'volume': 326797,
#   'volume_weighted_average': 184.7989,
#   'time': datetime.datetime(2024, 1, 9, 18, 0, tzinfo=<UTC>)},
#  {'open_price': 184.83,
#   'close_price': 184.5382,
#   'high_price': 184.85,
#   'low_price': 184.51,
#   'number_of_trades': 3379,
#   'volume': 231670,
#   'volume_weighted_average': 184.6244,
#   'time': datetime.datetime(2024, 1, 9, 18, 5, tzinfo=<UTC>)},
#  {'open_price': 184.53,
#   'close_price': 184.76,
#   'high_price': 184.77,
#   'low_price': 184.53,
#   'number_of_trades': 3056,
#   'volume': 239647,
#   'volume_weighted_average': 184.6818,
#   'time': datetime.datetime(2024, 1, 9, 18, 10, tzinfo=<UTC>)},
#  {'open_price': 184.76,
#   'close_price': 184.68,
#   'high_price': 184.775,
#   'low_price': 184.65,
#   'number_of_trades': 2930,
#   'volume': 215536,
#   'volume_weighted_average': 184.7143,
#   'time': datetime.datetime(2024, 1, 9, 18, 15, tzinfo=<UTC>)},
#  {'open_price': 184.68,
#   'close_price': 184.4579,
#   'high_price': 184.7,
#   'low_price': 184.4422,
#   'number_of_trades': 3703,
#   'volume': 254408,
#   'volume_weighted_average': 184.5765,
#   'time': datetime.datetime(2024, 1, 9, 18, 20, tzinfo=<UTC>)},
#  {'open_price': 184.46,
#   'close_price': 184.4,
#   'high_price': 184.5101,
#   'low_price': 184.39,
#   'number_of_trades': 3711,
#   'volume': 285663,
#   'volume_weighted_average': 184.4398,
#   'time': datetime.datetime(2024, 1, 9, 18, 25, tzinfo=<UTC>)},
#  {'open_price': 184.4,
#   'close_price': 184.06,
#   'high_price': 184.4,
#   'low_price': 184.04,
#   'number_of_trades': 6210,
#   'volume': 474179,
#   'volume_weighted_average': 184.1972,
#   'time': datetime.datetime(2024, 1, 9, 18, 30, tzinfo=<UTC>)},
#  {'open_price': 184.07,
#   'close_price': 184.145,
#   'high_price': 184.23,
#   'low_price': 184.05,
#   'number_of_trades': 3245,
#   'volume': 243949,
#   'volume_weighted_average': 184.1659,
#   'time': datetime.datetime(2024, 1, 9, 18, 35, tzinfo=<UTC>)},
#  {'open_price': 184.15,
#   'close_price': 184.12,
#   'high_price': 184.18,
#   'low_price': 184.085,
#   'number_of_trades': 3000,
#   'volume': 192630,
#   'volume_weighted_average': 184.1446,
#   'time': datetime.datetime(2024, 1, 9, 18, 40, tzinfo=<UTC>)},
#  {'open_price': 184.115,
#   'close_price': 184.3799,
#   'high_price': 184.38,
#   'low_price': 184.092,
#   'number_of_trades': 3356,
#   'volume': 297338,
#   'volume_weighted_average': 184.2519,
#   'time': datetime.datetime(2024, 1, 9, 18, 45, tzinfo=<UTC>)},
#  {'open_price': 184.37,
#   'close_price': 184.69,
#   'high_price': 184.69,
#   'low_price': 184.35,
#   'number_of_trades': 3848,
#   'volume': 312690,
#   'volume_weighted_average': 184.5494,
#   'time': datetime.datetime(2024, 1, 9, 18, 50, tzinfo=<UTC>)},
#  {'open_price': 184.685,
#   'close_price': 184.48,
#   'high_price': 184.73,
#   'low_price': 184.42,
#   'number_of_trades': 3257,
#   'volume': 273843,
#   'volume_weighted_average': 184.5792,
#   'time': datetime.datetime(2024, 1, 9, 18, 55, tzinfo=<UTC>)},
#  {'open_price': 184.49,
#   'close_price': 184.64,
#   'high_price': 184.68,
#   'low_price': 184.485,
#   'number_of_trades': 2842,
#   'volume': 216645,
#   'volume_weighted_average': 184.621,
#   'time': datetime.datetime(2024, 1, 9, 19, 0, tzinfo=<UTC>)},
#  {'open_price': 184.64,
#   'close_price': 184.61,
#   'high_price': 184.685,
#   'low_price': 184.57,
#   'number_of_trades': 2909,
#   'volume': 194597,
#   'volume_weighted_average': 184.6241,
#   'time': datetime.datetime(2024, 1, 9, 19, 5, tzinfo=<UTC>)},
#  {'open_price': 184.6199,
#   'close_price': 184.475,
#   'high_price': 184.64,
#   'low_price': 184.46,
#   'number_of_trades': 2993,
#   'volume': 210046,
#   'volume_weighted_average': 184.5413,
#   'time': datetime.datetime(2024, 1, 9, 19, 10, tzinfo=<UTC>)},
#  {'open_price': 184.48,
#   'close_price': 184.43,
#   'high_price': 184.55,
#   'low_price': 184.33,
#   'number_of_trades': 3661,
#   'volume': 249603,
#   'volume_weighted_average': 184.4327,
#   'time': datetime.datetime(2024, 1, 9, 19, 15, tzinfo=<UTC>)},
#  {'open_price': 184.43,
#   'close_price': 184.405,
#   'high_price': 184.54,
#   'low_price': 184.35,
#   'number_of_trades': 2945,
#   'volume': 240591,
#   'volume_weighted_average': 184.4439,
#   'time': datetime.datetime(2024, 1, 9, 19, 20, tzinfo=<UTC>)},
#  {'open_price': 184.4,
#   'close_price': 184.315,
#   'high_price': 184.45,
#   'low_price': 184.215,
#   'number_of_trades': 3361,
#   'volume': 270879,
#   'volume_weighted_average': 184.3178,
#   'time': datetime.datetime(2024, 1, 9, 19, 25, tzinfo=<UTC>)},
#  {'open_price': 184.3101,
#   'close_price': 184.5,
#   'high_price': 184.545,
#   'low_price': 184.3002,
#   'number_of_trades': 3156,
#   'volume': 236737,
#   'volume_weighted_average': 184.4251,
#   'time': datetime.datetime(2024, 1, 9, 19, 30, tzinfo=<UTC>)},
#  {'open_price': 184.49,
#   'close_price': 184.54,
#   'high_price': 184.57,
#   'low_price': 184.45,
#   'number_of_trades': 3095,
#   'volume': 202393,
#   'volume_weighted_average': 184.5256,
#   'time': datetime.datetime(2024, 1, 9, 19, 35, tzinfo=<UTC>)},
#  {'open_price': 184.55,
#   'close_price': 184.495,
#   'high_price': 184.59,
#   'low_price': 184.42,
#   'number_of_trades': 3383,
#   'volume': 241420,
#   'volume_weighted_average': 184.4957,
#   'time': datetime.datetime(2024, 1, 9, 19, 40, tzinfo=<UTC>)},
#  {'open_price': 184.495,
#   'close_price': 184.6,
#   'high_price': 184.66,
#   'low_price': 184.465,
#   'number_of_trades': 3775,
#   'volume': 296456,
#   'volume_weighted_average': 184.5668,
#   'time': datetime.datetime(2024, 1, 9, 19, 45, tzinfo=<UTC>)},
#  {'open_price': 184.6,
#   'close_price': 184.6274,
#   'high_price': 184.67,
#   'low_price': 184.545,
#   'number_of_trades': 3872,
#   'volume': 299488,
#   'volume_weighted_average': 184.6113,
#   'time': datetime.datetime(2024, 1, 9, 19, 50, tzinfo=<UTC>)},
#  {'open_price': 184.63,
#   'close_price': 184.6102,
#   'high_price': 184.635,
#   'low_price': 184.51,
#   'number_of_trades': 3221,
#   'volume': 268561,
#   'volume_weighted_average': 184.5816,
#   'time': datetime.datetime(2024, 1, 9, 19, 55, tzinfo=<UTC>)},
#  {'open_price': 184.62,
#   'close_price': 184.645,
#   'high_price': 184.65,
#   'low_price': 184.5699,
#   'number_of_trades': 3959,
#   'volume': 398858,
#   'volume_weighted_average': 184.6152,
#   'time': datetime.datetime(2024, 1, 9, 20, 0, tzinfo=<UTC>)},
#  {'open_price': 184.65,
#   'close_price': 184.56,
#   'high_price': 184.6867,
#   'low_price': 184.425,
#   'number_of_trades': 4134,
#   'volume': 354899,
#   'volume_weighted_average': 184.5539,
#   'time': datetime.datetime(2024, 1, 9, 20, 5, tzinfo=<UTC>)},
#  {'open_price': 184.56,
#   'close_price': 184.6001,
#   'high_price': 184.71,
#   'low_price': 184.56,
#   'number_of_trades': 4161,
#   'volume': 331457,
#   'volume_weighted_average': 184.629,
#   'time': datetime.datetime(2024, 1, 9, 20, 10, tzinfo=<UTC>)},
#  {'open_price': 184.609,
#   'close_price': 184.77,
#   'high_price': 184.785,
#   'low_price': 184.6,
#   'number_of_trades': 4475,
#   'volume': 353930,
#   'volume_weighted_average': 184.7044,
#   'time': datetime.datetime(2024, 1, 9, 20, 15, tzinfo=<UTC>)},
#  {'open_price': 184.77,
#   'close_price': 184.672,
#   'high_price': 184.9,
#   'low_price': 184.665,
#   'number_of_trades': 4947,
#   'volume': 418310,
#   'volume_weighted_average': 184.8038,
#   'time': datetime.datetime(2024, 1, 9, 20, 20, tzinfo=<UTC>)},
#  {'open_price': 184.675,
#   'close_price': 184.78,
#   'high_price': 184.845,
#   'low_price': 184.67,
#   'number_of_trades': 3675,
#   'volume': 247517,
#   'volume_weighted_average': 184.7725,
#   'time': datetime.datetime(2024, 1, 9, 20, 25, tzinfo=<UTC>)},
#  {'open_price': 184.78,
#   'close_price': 184.77,
#   'high_price': 184.84,
#   'low_price': 184.69,
#   'number_of_trades': 4084,
#   'volume': 271156,
#   'volume_weighted_average': 184.7739,
#   'time': datetime.datetime(2024, 1, 9, 20, 30, tzinfo=<UTC>)},
#  {'open_price': 184.76,
#   'close_price': 184.735,
#   'high_price': 184.84,
#   'low_price': 184.685,
#   'number_of_trades': 4416,
#   'volume': 341323,
#   'volume_weighted_average': 184.7516,
#   'time': datetime.datetime(2024, 1, 9, 20, 35, tzinfo=<UTC>)},
#  {'open_price': 184.74,
#   'close_price': 184.6401,
#   'high_price': 184.77,
#   'low_price': 184.54,
#   'number_of_trades': 5720,
#   'volume': 469536,
#   'volume_weighted_average': 184.6235,
#   'time': datetime.datetime(2024, 1, 9, 20, 40, tzinfo=<UTC>)},
#  {'open_price': 184.64,
#   'close_price': 184.595,
#   'high_price': 184.7,
#   'low_price': 184.57,
#   'number_of_trades': 5058,
#   'volume': 385005,
#   'volume_weighted_average': 184.637,
#   'time': datetime.datetime(2024, 1, 9, 20, 45, tzinfo=<UTC>)},
#  {'open_price': 184.6,
#   'close_price': 184.97,
#   'high_price': 185.02,
#   'low_price': 184.41,
#   'number_of_trades': 12799,
#   'volume': 1138023.0,
#   'volume_weighted_average': 184.767,
#   'time': datetime.datetime(2024, 1, 9, 20, 50, tzinfo=<UTC>)},
#  {'open_price': 184.98,
#   'close_price': 185.13,
#   'high_price': 185.15,
#   'low_price': 184.96,
#   'number_of_trades': 22463,
#   'volume': 3523633.0,
#   'volume_weighted_average': 184.9469,
#   'time': datetime.datetime(2024, 1, 9, 20, 55, tzinfo=<UTC>)},
#  {'open_price': 185.14,
#   'close_price': 185.16,
#   'high_price': 185.16,
#   'low_price': 185.03,
#   'number_of_trades': 454,
#   'volume': 411177,
#   'volume_weighted_average': 185.1373,
#   'time': datetime.datetime(2024, 1, 9, 21, 0, tzinfo=<UTC>)},
#  {'open_price': 185.15,
#   'close_price': 185.18,
#   'high_price': 185.56,
#   'low_price': 185.14,
#   'number_of_trades': 242,
#   'volume': 19363,
#   'volume_weighted_average': 185.2032,
#   'time': datetime.datetime(2024, 1, 9, 21, 5, tzinfo=<UTC>)},
#  {'open_price': 185.16,
#   'close_price': 185.14,
#   'high_price': 185.17,
#   'low_price': 185.14,
#   'number_of_trades': 150,
#   'volume': 6664,
#   'volume_weighted_average': 185.1477,
#   'time': datetime.datetime(2024, 1, 9, 21, 10, tzinfo=<UTC>)},
#  {'open_price': 185.14,
#   'close_price': 185.17,
#   'high_price': 185.19,
#   'low_price': 185.14,
#   'number_of_trades': 106,
#   'volume': 10766,
#   'volume_weighted_average': 185.1634,
#   'time': datetime.datetime(2024, 1, 9, 21, 15, tzinfo=<UTC>)},
#  {'open_price': 185.17,
#   'close_price': 185.18,
#   'high_price': 185.2,
#   'low_price': 185.17,
#   'number_of_trades': 118,
#   'volume': 3353,
#   'volume_weighted_average': 185.1785,
#   'time': datetime.datetime(2024, 1, 9, 21, 20, tzinfo=<UTC>)},
#  {'open_price': 185.17,
#   'close_price': 185.14,
#   'high_price': 185.19,
#   'low_price': 185.14,
#   'number_of_trades': 96,
#   'volume': 2890,
#   'volume_weighted_average': 185.1663,
#   'time': datetime.datetime(2024, 1, 9, 21, 25, tzinfo=<UTC>)},
#  {'open_price': 185.14,
#   'close_price': 185.14,
#   'high_price': 185.23,
#   'low_price': 185.1203,
#   'number_of_trades': 155,
#   'volume': 8546,
#   'volume_weighted_average': 185.1447,
#   'time': datetime.datetime(2024, 1, 9, 21, 30, tzinfo=<UTC>)},
#  {'open_price': 185.14,
#   'close_price': 185.19,
#   'high_price': 185.19,
#   'low_price': 185.14,
#   'number_of_trades': 104,
#   'volume': 9402,
#   'volume_weighted_average': 185.1466,
#   'time': datetime.datetime(2024, 1, 9, 21, 35, tzinfo=<UTC>)},
#  {'open_price': 185.1999,
#   'close_price': 185.19,
#   'high_price': 185.1999,
#   'low_price': 185.17,
#   'number_of_trades': 39,
#   'volume': 2624,
#   'volume_weighted_average': 185.1733,
#   'time': datetime.datetime(2024, 1, 9, 21, 40, tzinfo=<UTC>)},
#  {'open_price': 185.18,
#   'close_price': 185.18,
#   'high_price': 185.19,
#   'low_price': 185.18,
#   'number_of_trades': 44,
#   'volume': 767,
#   'volume_weighted_average': 185.1839,
#   'time': datetime.datetime(2024, 1, 9, 21, 45, tzinfo=<UTC>)},
#  {'open_price': 185.19,
#   'close_price': 185.18,
#   'high_price': 185.2,
#   'low_price': 185.18,
#   'number_of_trades': 98,
#   'volume': 352397,
#   'volume_weighted_average': 185.1402,
#   'time': datetime.datetime(2024, 1, 9, 21, 50, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.23,
#   'high_price': 185.23,
#   'low_price': 185.2,
#   'number_of_trades': 101,
#   'volume': 2913,
#   'volume_weighted_average': 185.2099,
#   'time': datetime.datetime(2024, 1, 9, 21, 55, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.2,
#   'high_price': 185.2,
#   'low_price': 185.2,
#   'number_of_trades': 44,
#   'volume': 737,
#   'volume_weighted_average': 185.1976,
#   'time': datetime.datetime(2024, 1, 9, 22, 0, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.21,
#   'high_price': 185.2107,
#   'low_price': 185.2,
#   'number_of_trades': 57,
#   'volume': 3090,
#   'volume_weighted_average': 185.6734,
#   'time': datetime.datetime(2024, 1, 9, 22, 5, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.23,
#   'high_price': 185.23,
#   'low_price': 185.2,
#   'number_of_trades': 131,
#   'volume': 5254,
#   'volume_weighted_average': 185.2183,
#   'time': datetime.datetime(2024, 1, 9, 22, 10, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.22,
#   'high_price': 185.22,
#   'low_price': 185.22,
#   'number_of_trades': 52,
#   'volume': 1470,
#   'volume_weighted_average': 185.2202,
#   'time': datetime.datetime(2024, 1, 9, 22, 15, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.21,
#   'high_price': 185.21,
#   'low_price': 185.2,
#   'number_of_trades': 36,
#   'volume': 1256,
#   'volume_weighted_average': 185.2092,
#   'time': datetime.datetime(2024, 1, 9, 22, 20, tzinfo=<UTC>)},
#  {'open_price': 185.21,
#   'close_price': 185.21,
#   'high_price': 185.21,
#   'low_price': 185.21,
#   'number_of_trades': 36,
#   'volume': 465,
#   'volume_weighted_average': 185.212,
#   'time': datetime.datetime(2024, 1, 9, 22, 25, tzinfo=<UTC>)},
#  {'open_price': 185.21,
#   'close_price': 185.22,
#   'high_price': 185.22,
#   'low_price': 185.21,
#   'number_of_trades': 13,
#   'volume': 1328,
#   'volume_weighted_average': 185.2112,
#   'time': datetime.datetime(2024, 1, 9, 22, 30, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.22,
#   'high_price': 185.22,
#   'low_price': 185.2,
#   'number_of_trades': 69,
#   'volume': 2030,
#   'volume_weighted_average': 185.2115,
#   'time': datetime.datetime(2024, 1, 9, 22, 35, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.22,
#   'high_price': 185.22,
#   'low_price': 185.22,
#   'number_of_trades': 19,
#   'volume': 733,
#   'volume_weighted_average': 185.219,
#   'time': datetime.datetime(2024, 1, 9, 22, 40, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.24,
#   'high_price': 185.24,
#   'low_price': 185.22,
#   'number_of_trades': 60,
#   'volume': 2045,
#   'volume_weighted_average': 185.2233,
#   'time': datetime.datetime(2024, 1, 9, 22, 45, tzinfo=<UTC>)},
#  {'open_price': 185.25,
#   'close_price': 185.22,
#   'high_price': 185.28,
#   'low_price': 185.22,
#   'number_of_trades': 62,
#   'volume': 1736,
#   'volume_weighted_average': 185.2478,
#   'time': datetime.datetime(2024, 1, 9, 22, 50, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.23,
#   'high_price': 185.23,
#   'low_price': 185.22,
#   'number_of_trades': 34,
#   'volume': 652,
#   'volume_weighted_average': 185.2367,
#   'time': datetime.datetime(2024, 1, 9, 22, 55, tzinfo=<UTC>)},
#  {'open_price': 185.23,
#   'close_price': 185.21,
#   'high_price': 185.23,
#   'low_price': 185.21,
#   'number_of_trades': 68,
#   'volume': 3188,
#   'volume_weighted_average': 185.2193,
#   'time': datetime.datetime(2024, 1, 9, 23, 0, tzinfo=<UTC>)},
#  {'open_price': 185.21,
#   'close_price': 185.2,
#   'high_price': 185.26,
#   'low_price': 185.2,
#   'number_of_trades': 58,
#   'volume': 2434,
#   'volume_weighted_average': 185.2193,
#   'time': datetime.datetime(2024, 1, 9, 23, 5, tzinfo=<UTC>)},
#  {'open_price': 185.18,
#   'close_price': 185.19,
#   'high_price': 185.19,
#   'low_price': 185.18,
#   'number_of_trades': 48,
#   'volume': 1716,
#   'volume_weighted_average': 185.1854,
#   'time': datetime.datetime(2024, 1, 9, 23, 10, tzinfo=<UTC>)},
#  {'open_price': 185.1987,
#   'close_price': 185.2,
#   'high_price': 185.2,
#   'low_price': 185.16,
#   'number_of_trades': 33,
#   'volume': 1884,
#   'volume_weighted_average': 185.1742,
#   'time': datetime.datetime(2024, 1, 9, 23, 15, tzinfo=<UTC>)},
#  {'open_price': 185.15,
#   'close_price': 185.19,
#   'high_price': 185.19,
#   'low_price': 185.15,
#   'number_of_trades': 36,
#   'volume': 936,
#   'volume_weighted_average': 185.1769,
#   'time': datetime.datetime(2024, 1, 9, 23, 20, tzinfo=<UTC>)},
#  {'open_price': 185.15,
#   'close_price': 185.15,
#   'high_price': 185.15,
#   'low_price': 185.15,
#   'number_of_trades': 13,
#   'volume': 418,
#   'volume_weighted_average': 185.1512,
#   'time': datetime.datetime(2024, 1, 9, 23, 25, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.18,
#   'high_price': 185.22,
#   'low_price': 185.18,
#   'number_of_trades': 39,
#   'volume': 554,
#   'volume_weighted_average': 185.1905,
#   'time': datetime.datetime(2024, 1, 9, 23, 30, tzinfo=<UTC>)},
#  {'open_price': 185.15,
#   'close_price': 185.15,
#   'high_price': 185.15,
#   'low_price': 185.15,
#   'number_of_trades': 17,
#   'volume': 244,
#   'volume_weighted_average': 185.153,
#   'time': datetime.datetime(2024, 1, 9, 23, 40, tzinfo=<UTC>)},
#  {'open_price': 185.2,
#   'close_price': 185.2,
#   'high_price': 185.2,
#   'low_price': 185.2,
#   'number_of_trades': 6,
#   'volume': 1043,
#   'volume_weighted_average': 185.1998,
#   'time': datetime.datetime(2024, 1, 9, 23, 45, tzinfo=<UTC>)},
#  {'open_price': 185.22,
#   'close_price': 185.36,
#   'high_price': 185.36,
#   'low_price': 185.21,
#   'number_of_trades': 77,
#   'volume': 3095,
#   'volume_weighted_average': 185.2794,
#   'time': datetime.datetime(2024, 1, 9, 23, 50, tzinfo=<UTC>)},
#  {'open_price': 185.3601,
#   'close_price': 185.48,
#   'high_price': 185.48,
#   'low_price': 185.36,
#   'number_of_trades': 52,
#   'volume': 2642,
#   'volume_weighted_average': 185.3875,
#   'time': datetime.datetime(2024, 1, 9, 23, 55, tzinfo=<UTC>)},
#  {'open_price': 185.47,
#   'close_price': 185.44,
#   'high_price': 185.47,
#   'low_price': 185.44,
#   'number_of_trades': 55,
#   'volume': 2321,
#   'volume_weighted_average': 185.4439,
#   'time': datetime.datetime(2024, 1, 10, 0, 0, tzinfo=<UTC>)},
#  {'open_price': 185.45,
#   'close_price': 185.5,
#   'high_price': 185.5,
#   'low_price': 185.4,
#   'number_of_trades': 71,
#   'volume': 3173,
#   'volume_weighted_average': 185.4708,
#   'time': datetime.datetime(2024, 1, 10, 0, 5, tzinfo=<UTC>)},
#  {'open_price': 185.43,
#   'close_price': 185.44,
#   'high_price': 185.45,
#   'low_price': 185.43,
#   'number_of_trades': 43,
#   'volume': 1067,
#   'volume_weighted_average': 185.4432,
#   'time': datetime.datetime(2024, 1, 10, 0, 15, tzinfo=<UTC>)},
#  {'open_price': 185.48,
#   'close_price': 185.45,
#   'high_price': 185.48,
#   'low_price': 185.44,
#   'number_of_trades': 50,
#   'volume': 2381,
#   'volume_weighted_average': 185.4738,
#   'time': datetime.datetime(2024, 1, 10, 0, 20, tzinfo=<UTC>)},
#  {'open_price': 185.46,
#   'close_price': 185.4999,
#   'high_price': 185.5,
#   'low_price': 185.46,
#   'number_of_trades': 67,
#   'volume': 2798,
#   'volume_weighted_average': 185.4874,
#   'time': datetime.datetime(2024, 1, 10, 0, 25, tzinfo=<UTC>)},
#  {'open_price': 185.42,
#   'close_price': 185.48,
#   'high_price': 185.48,
#   'low_price': 185.42,
#   'number_of_trades': 35,
#   'volume': 740,
#   'volume_weighted_average': 185.454,
#   'time': datetime.datetime(2024, 1, 10, 0, 30, tzinfo=<UTC>)},
#  {'open_price': 185.43,
#   'close_price': 185.42,
#   'high_price': 185.43,
#   'low_price': 185.42,
#   'number_of_trades': 27,
#   'volume': 812,
#   'volume_weighted_average': 185.4241,
#   'time': datetime.datetime(2024, 1, 10, 0, 35, tzinfo=<UTC>)},
#  {'open_price': 185.47,
#   'close_price': 185.42,
#   'high_price': 185.47,
#   'low_price': 185.42,
#   'number_of_trades': 46,
#   'volume': 1161,
#   'volume_weighted_average': 185.4449,
#   'time': datetime.datetime(2024, 1, 10, 0, 45, tzinfo=<UTC>)},
#  {'open_price': 185.39,
#   'close_price': 185.5,
#   'high_price': 185.5,
#   'low_price': 185.37,
#   'number_of_trades': 78,
#   'volume': 5738,
#   'volume_weighted_average': 185.4344,
#   'time': datetime.datetime(2024, 1, 10, 0, 50, tzinfo=<UTC>)},
#  {'open_price': 185.47,
#   'close_price': 185.41,
#   'high_price': 185.49,
#   'low_price': 185.33,
#   'number_of_trades': 67,
#   'volume': 3236,
#   'volume_weighted_average': 185.4314,
#   'time': datetime.datetime(2024, 1, 10, 0, 55, tzinfo=<UTC>)}]
