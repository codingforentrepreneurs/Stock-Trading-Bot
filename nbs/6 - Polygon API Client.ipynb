# %%
from decouple import config

# %%
assert config("POLOGYON_API_KEY", default=None, cast=str) is not None

# %%
import requests

# %%
ticker = "AAPL"
multiplier = "5"
timespan = "minute"
from_date = "2023-01-09"
to_date = "2023-01-09"
path = f"/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{from_date}/{to_date}"
url = f"https://api.polygon.io{path}?apiKey={POLOGYON_API_KEY}"

# %%
import pytz
from dataclasses import dataclass
from typing import Literal
from urllib.parse import urlencode
from datetime import datetime

POLOGYON_API_KEY = config("POLOGYON_API_KEY", default=None, cast=str)




def transform_polygon_result(result):
    unix_timestamp = result.get('t') / 1000.0
    utc_timestamp = datetime.fromtimestamp(unix_timestamp, tz=pytz.timezone('UTC'))
    return {
        'open_price': result['o'],
        'close_price': result['c'],
        'high_price': result['h'],
        'low_price': result['l'],
        'number_of_trades': result['n'],
        'volume': result['v'],
        'volume_weighted_average': result['vw'],
        'time': utc_timestamp,
    }


@dataclass
class PolygonAPIClient:
    ticker: str = "AAPL"
    multiplier: int = 5
    timespan:str = "minute"
    from_date:str = "2024-01-09"
    to_date:str = "2024-01-09"
    api_key:str = ""
    adjusted: bool = True 
    sort: Literal["asc", "desc"] = "asc"

    def get_api_key(self):
        return self.api_key or POLOGYON_API_KEY

    def get_headers(self):
        api_key = self.get_api_key()
        return {
            "Authorization": f"Bearer {api_key}"
        }

    def get_params(self):
        return {
            "adjusted": self.adjusted,
            "sort": self.sort
        }
    
    def generate_url(self, pass_auth=False):
        path = f"/v2/aggs/ticker/{self.ticker}/range/{self.multiplier}/{self.timespan}/{self.from_date}/{self.to_date}"
        url = f"https://api.polygon.io{path}"
        params = self.get_params()
        encoded_params = urlencode(params)
        url = f"{url}?{encoded_params}"
        if pass_auth:
            api_key = self.get_api_key()
            url += f"&api_key={api_key}"
        return url

    def fetch_data(self):
        headers = self.get_headers()
        url = self.generate_url()
        response = requests.get(url, headers=headers)
        response.raise_for_status() # not 200/201
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        results = data['results']
        dataset = []
        for result in results:
            dataset.append(
                transform_polygon_result(result)
            )
        return dataset

# %%
stock_api_client = PolygonAPIClient(ticker="GOOG", multiplier=1)
stock_api_client.generate_url()
# Out:
# 'https://api.polygon.io/v2/aggs/ticker/GOOG/range/1/minute/2024-01-09/2024-01-09?adjusted=True&sort=asc'

# %%
dataset = stock_api_client.get_stock_data()
dataset
# Out:
# [{'open_price': 140.41,
#   'close_price': 140.41,
#   'high_price': 140.41,
#   'low_price': 140.41,
#   'number_of_trades': 3,
#   'volume': 134,
#   'volume_weighted_average': 140.3984,
#   'time': datetime.datetime(2024, 1, 9, 9, 2, tzinfo=<UTC>)},
#  {'open_price': 140.4,
#   'close_price': 140.4,
#   'high_price': 140.4,
#   'low_price': 140.4,
#   'number_of_trades': 13,
#   'volume': 517,
#   'volume_weighted_average': 140.3535,
#   'time': datetime.datetime(2024, 1, 9, 9, 4, tzinfo=<UTC>)},
#  {'open_price': 140.32,
#   'close_price': 140.33,
#   'high_price': 140.33,
#   'low_price': 140.32,
#   'number_of_trades': 7,
#   'volume': 428,
#   'volume_weighted_average': 140.3273,
#   'time': datetime.datetime(2024, 1, 9, 9, 6, tzinfo=<UTC>)},
#  {'open_price': 140.06,
#   'close_price': 140.06,
#   'high_price': 140.06,
#   'low_price': 140.06,
#   'number_of_trades': 2,
#   'volume': 201,
#   'volume_weighted_average': 140.06,
#   'time': datetime.datetime(2024, 1, 9, 9, 11, tzinfo=<UTC>)},
#  {'open_price': 140.06,
#   'close_price': 140.06,
#   'high_price': 140.06,
#   'low_price': 140.06,
#   'number_of_trades': 6,
#   'volume': 334,
#   'volume_weighted_average': 140.059,
#   'time': datetime.datetime(2024, 1, 9, 9, 13, tzinfo=<UTC>)},
#  {'open_price': 140,
#   'close_price': 140,
#   'high_price': 140,
#   'low_price': 140,
#   'number_of_trades': 13,
#   'volume': 745,
#   'volume_weighted_average': 139.9987,
#   'time': datetime.datetime(2024, 1, 9, 9, 15, tzinfo=<UTC>)},
#  {'open_price': 139.92,
#   'close_price': 139.92,
#   'high_price': 139.92,
#   'low_price': 139.92,
#   'number_of_trades': 11,
#   'volume': 400,
#   'volume_weighted_average': 139.9203,
#   'time': datetime.datetime(2024, 1, 9, 9, 20, tzinfo=<UTC>)},
#  {'open_price': 139.89,
#   'close_price': 139.86,
#   'high_price': 139.89,
#   'low_price': 139.86,
#   'number_of_trades': 13,
#   'volume': 729,
#   'volume_weighted_average': 139.8927,
#   'time': datetime.datetime(2024, 1, 9, 9, 21, tzinfo=<UTC>)},
#  {'open_price': 139.9,
#   'close_price': 139.87,
#   'high_price': 139.9,
#   'low_price': 139.87,
#   'number_of_trades': 5,
#   'volume': 400,
#   'volume_weighted_average': 139.8825,
#   'time': datetime.datetime(2024, 1, 9, 9, 24, tzinfo=<UTC>)},
#  {'open_price': 139.87,
#   'close_price': 139.87,
#   'high_price': 139.87,
#   'low_price': 139.87,
#   'number_of_trades': 10,
#   'volume': 534,
#   'volume_weighted_average': 139.8692,
#   'time': datetime.datetime(2024, 1, 9, 9, 25, tzinfo=<UTC>)},
#  {'open_price': 140.11,
#   'close_price': 140.11,
#   'high_price': 140.11,
#   'low_price': 140.11,
#   'number_of_trades': 5,
#   'volume': 251,
#   'volume_weighted_average': 140.1109,
#   'time': datetime.datetime(2024, 1, 9, 9, 45, tzinfo=<UTC>)},
#  {'open_price': 140.15,
#   'close_price': 140.15,
#   'high_price': 140.15,
#   'low_price': 140.15,
#   'number_of_trades': 3,
#   'volume': 407,
#   'volume_weighted_average': 140.1525,
#   'time': datetime.datetime(2024, 1, 9, 9, 49, tzinfo=<UTC>)},
#  {'open_price': 140.12,
#   'close_price': 140.12,
#   'high_price': 140.12,
#   'low_price': 140.12,
#   'number_of_trades': 21,
#   'volume': 794,
#   'volume_weighted_average': 140.1169,
#   'time': datetime.datetime(2024, 1, 9, 10, 0, tzinfo=<UTC>)},
#  {'open_price': 140.05,
#   'close_price': 140.03,
#   'high_price': 140.05,
#   'low_price': 140,
#   'number_of_trades': 6,
#   'volume': 367,
#   'volume_weighted_average': 140.0229,
#   'time': datetime.datetime(2024, 1, 9, 10, 2, tzinfo=<UTC>)},
#  {'open_price': 140.13,
#   'close_price': 140.05,
#   'high_price': 140.13,
#   'low_price': 140.05,
#   'number_of_trades': 7,
#   'volume': 364,
#   'volume_weighted_average': 140.0792,
#   'time': datetime.datetime(2024, 1, 9, 10, 9, tzinfo=<UTC>)},
#  {'open_price': 140.07,
#   'close_price': 140.05,
#   'high_price': 140.07,
#   'low_price': 140.05,
#   'number_of_trades': 6,
#   'volume': 272,
#   'volume_weighted_average': 140.0601,
#   'time': datetime.datetime(2024, 1, 9, 10, 39, tzinfo=<UTC>)},
#  {'open_price': 139.86,
#   'close_price': 139.86,
#   'high_price': 139.86,
#   'low_price': 139.86,
#   'number_of_trades': 10,
#   'volume': 389,
#   'volume_weighted_average': 139.8591,
#   'time': datetime.datetime(2024, 1, 9, 10, 45, tzinfo=<UTC>)},
#  {'open_price': 139.95,
#   'close_price': 139.95,
#   'high_price': 139.95,
#   'low_price': 139.95,
#   'number_of_trades': 8,
#   'volume': 500,
#   'volume_weighted_average': 139.941,
#   'time': datetime.datetime(2024, 1, 9, 10, 51, tzinfo=<UTC>)},
#  {'open_price': 139.96,
#   'close_price': 140,
#   'high_price': 140,
#   'low_price': 139.96,
#   'number_of_trades': 30,
#   'volume': 1189,
#   'volume_weighted_average': 139.9696,
#   'time': datetime.datetime(2024, 1, 9, 11, 0, tzinfo=<UTC>)},
#  {'open_price': 140,
#   'close_price': 140,
#   'high_price': 140,
#   'low_price': 140,
#   'number_of_trades': 19,
#   'volume': 1040,
#   'volume_weighted_average': 139.9927,
#   'time': datetime.datetime(2024, 1, 9, 11, 1, tzinfo=<UTC>)},
#  {'open_price': 139.92,
#   'close_price': 139.92,
#   'high_price': 139.92,
#   'low_price': 139.92,
#   'number_of_trades': 1,
#   'volume': 150,
#   'volume_weighted_average': 139.92,
#   'time': datetime.datetime(2024, 1, 9, 11, 9, tzinfo=<UTC>)},
#  {'open_price': 139.91,
#   'close_price': 139.9,
#   'high_price': 139.91,
#   'low_price': 139.9,
#   'number_of_trades': 6,
#   'volume': 430,
#   'volume_weighted_average': 139.8955,
#   'time': datetime.datetime(2024, 1, 9, 11, 11, tzinfo=<UTC>)},
#  {'open_price': 139.86,
#   'close_price': 139.86,
#   'high_price': 139.86,
#   'low_price': 139.86,
#   'number_of_trades': 10,
#   'volume': 414,
#   'volume_weighted_average': 139.8497,
#   'time': datetime.datetime(2024, 1, 9, 11, 37, tzinfo=<UTC>)},
#  {'open_price': 139.85,
#   'close_price': 139.85,
#   'high_price': 139.85,
#   'low_price': 139.85,
#   'number_of_trades': 6,
#   'volume': 344,
#   'volume_weighted_average': 139.8573,
#   'time': datetime.datetime(2024, 1, 9, 11, 38, tzinfo=<UTC>)},
#  {'open_price': 139.85,
#   'close_price': 139.9,
#   'high_price': 139.9,
#   'low_price': 139.85,
#   'number_of_trades': 13,
#   'volume': 767,
#   'volume_weighted_average': 139.8785,
#   'time': datetime.datetime(2024, 1, 9, 11, 41, tzinfo=<UTC>)},
#  {'open_price': 139.9,
#   'close_price': 139.9,
#   'high_price': 139.9,
#   'low_price': 139.9,
#   'number_of_trades': 3,
#   'volume': 187,
#   'volume_weighted_average': 139.8988,
#   'time': datetime.datetime(2024, 1, 9, 11, 46, tzinfo=<UTC>)},
#  {'open_price': 139.89,
#   'close_price': 139.89,
#   'high_price': 139.89,
#   'low_price': 139.89,
#   'number_of_trades': 8,
#   'volume': 477,
#   'volume_weighted_average': 139.8706,
#   'time': datetime.datetime(2024, 1, 9, 11, 52, tzinfo=<UTC>)},
#  {'open_price': 139.85,
#   'close_price': 139.85,
#   'high_price': 139.85,
#   'low_price': 139.85,
#   'number_of_trades': 21,
#   'volume': 606,
#   'volume_weighted_average': 139.8207,
#   'time': datetime.datetime(2024, 1, 9, 11, 53, tzinfo=<UTC>)},
#  {'open_price': 139.78,
#   'close_price': 139.78,
#   'high_price': 139.78,
#   'low_price': 139.78,
#   'number_of_trades': 12,
#   'volume': 225,
#   'volume_weighted_average': 139.7593,
#   'time': datetime.datetime(2024, 1, 9, 11, 54, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 2,
#   'volume': 265,
#   'volume_weighted_average': 139.8001,
#   'time': datetime.datetime(2024, 1, 9, 11, 55, tzinfo=<UTC>)},
#  {'open_price': 139.86,
#   'close_price': 139.86,
#   'high_price': 139.86,
#   'low_price': 139.86,
#   'number_of_trades': 9,
#   'volume': 355,
#   'volume_weighted_average': 139.8581,
#   'time': datetime.datetime(2024, 1, 9, 11, 57, tzinfo=<UTC>)},
#  {'open_price': 139.86,
#   'close_price': 139.9,
#   'high_price': 140,
#   'low_price': 139.84,
#   'number_of_trades': 109,
#   'volume': 6650,
#   'volume_weighted_average': 139.8956,
#   'time': datetime.datetime(2024, 1, 9, 12, 0, tzinfo=<UTC>)},
#  {'open_price': 139.9,
#   'close_price': 139.8,
#   'high_price': 139.9,
#   'low_price': 139.8,
#   'number_of_trades': 15,
#   'volume': 666,
#   'volume_weighted_average': 139.8311,
#   'time': datetime.datetime(2024, 1, 9, 12, 1, tzinfo=<UTC>)},
#  {'open_price': 139.75,
#   'close_price': 139.75,
#   'high_price': 139.75,
#   'low_price': 139.75,
#   'number_of_trades': 18,
#   'volume': 534,
#   'volume_weighted_average': 139.7666,
#   'time': datetime.datetime(2024, 1, 9, 12, 6, tzinfo=<UTC>)},
#  {'open_price': 139.87,
#   'close_price': 139.87,
#   'high_price': 139.87,
#   'low_price': 139.87,
#   'number_of_trades': 8,
#   'volume': 292,
#   'volume_weighted_average': 139.8707,
#   'time': datetime.datetime(2024, 1, 9, 12, 7, tzinfo=<UTC>)},
#  {'open_price': 139.85,
#   'close_price': 139.85,
#   'high_price': 139.85,
#   'low_price': 139.85,
#   'number_of_trades': 12,
#   'volume': 410,
#   'volume_weighted_average': 139.8155,
#   'time': datetime.datetime(2024, 1, 9, 12, 12, tzinfo=<UTC>)},
#  {'open_price': 139.9,
#   'close_price': 139.9,
#   'high_price': 139.9,
#   'low_price': 139.9,
#   'number_of_trades': 41,
#   'volume': 1933,
#   'volume_weighted_average': 139.8895,
#   'time': datetime.datetime(2024, 1, 9, 12, 17, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.75,
#   'high_price': 139.8,
#   'low_price': 139.75,
#   'number_of_trades': 18,
#   'volume': 528,
#   'volume_weighted_average': 139.7809,
#   'time': datetime.datetime(2024, 1, 9, 12, 29, tzinfo=<UTC>)},
#  {'open_price': 139.75,
#   'close_price': 139.75,
#   'high_price': 139.75,
#   'low_price': 139.75,
#   'number_of_trades': 16,
#   'volume': 534,
#   'volume_weighted_average': 139.7325,
#   'time': datetime.datetime(2024, 1, 9, 12, 30, tzinfo=<UTC>)},
#  {'open_price': 139.75,
#   'close_price': 139.68,
#   'high_price': 139.75,
#   'low_price': 139.68,
#   'number_of_trades': 17,
#   'volume': 605,
#   'volume_weighted_average': 139.7457,
#   'time': datetime.datetime(2024, 1, 9, 12, 31, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.72,
#   'high_price': 139.8,
#   'low_price': 139.72,
#   'number_of_trades': 12,
#   'volume': 404,
#   'volume_weighted_average': 139.7485,
#   'time': datetime.datetime(2024, 1, 9, 12, 32, tzinfo=<UTC>)},
#  {'open_price': 139.85,
#   'close_price': 139.85,
#   'high_price': 139.85,
#   'low_price': 139.85,
#   'number_of_trades': 16,
#   'volume': 450,
#   'volume_weighted_average': 139.8533,
#   'time': datetime.datetime(2024, 1, 9, 12, 38, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 6,
#   'volume': 192,
#   'volume_weighted_average': 139.8119,
#   'time': datetime.datetime(2024, 1, 9, 12, 41, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 2,
#   'volume': 1000,
#   'volume_weighted_average': 139.8,
#   'time': datetime.datetime(2024, 1, 9, 12, 43, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 12,
#   'volume': 954,
#   'volume_weighted_average': 139.8104,
#   'time': datetime.datetime(2024, 1, 9, 12, 50, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 4,
#   'volume': 287,
#   'volume_weighted_average': 139.8,
#   'time': datetime.datetime(2024, 1, 9, 12, 51, tzinfo=<UTC>)},
#  {'open_price': 139.88,
#   'close_price': 139.88,
#   'high_price': 139.88,
#   'low_price': 139.88,
#   'number_of_trades': 7,
#   'volume': 1026,
#   'volume_weighted_average': 139.8795,
#   'time': datetime.datetime(2024, 1, 9, 12, 54, tzinfo=<UTC>)},
#  {'open_price': 139.88,
#   'close_price': 139.9,
#   'high_price': 139.9,
#   'low_price': 139.88,
#   'number_of_trades': 30,
#   'volume': 1796,
#   'volume_weighted_average': 139.8961,
#   'time': datetime.datetime(2024, 1, 9, 12, 55, tzinfo=<UTC>)},
#  {'open_price': 139.88,
#   'close_price': 139.88,
#   'high_price': 139.88,
#   'low_price': 139.88,
#   'number_of_trades': 14,
#   'volume': 525,
#   'volume_weighted_average': 139.8806,
#   'time': datetime.datetime(2024, 1, 9, 12, 56, tzinfo=<UTC>)},
#  {'open_price': 139.9,
#   'close_price': 139.9,
#   'high_price': 139.9,
#   'low_price': 139.9,
#   'number_of_trades': 8,
#   'volume': 413,
#   'volume_weighted_average': 139.893,
#   'time': datetime.datetime(2024, 1, 9, 12, 57, tzinfo=<UTC>)},
#  {'open_price': 139.86,
#   'close_price': 139.84,
#   'high_price': 140,
#   'low_price': 139.8,
#   'number_of_trades': 93,
#   'volume': 6291,
#   'volume_weighted_average': 139.9077,
#   'time': datetime.datetime(2024, 1, 9, 13, 0, tzinfo=<UTC>)},
#  {'open_price': 139.82,
#   'close_price': 139.8,
#   'high_price': 139.82,
#   'low_price': 139.8,
#   'number_of_trades': 56,
#   'volume': 638,
#   'volume_weighted_average': 139.9493,
#   'time': datetime.datetime(2024, 1, 9, 13, 1, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 31,
#   'volume': 844,
#   'volume_weighted_average': 140.0494,
#   'time': datetime.datetime(2024, 1, 9, 13, 2, tzinfo=<UTC>)},
#  {'open_price': 140.62,
#   'close_price': 140.78,
#   'high_price': 140.78,
#   'low_price': 140.62,
#   'number_of_trades': 54,
#   'volume': 2071,
#   'volume_weighted_average': 140.6711,
#   'time': datetime.datetime(2024, 1, 9, 13, 3, tzinfo=<UTC>)},
#  {'open_price': 139.79,
#   'close_price': 139.73,
#   'high_price': 139.79,
#   'low_price': 139.73,
#   'number_of_trades': 42,
#   'volume': 1946,
#   'volume_weighted_average': 139.7779,
#   'time': datetime.datetime(2024, 1, 9, 13, 4, tzinfo=<UTC>)},
#  {'open_price': 139.7,
#   'close_price': 139.7,
#   'high_price': 139.7,
#   'low_price': 139.7,
#   'number_of_trades': 12,
#   'volume': 418,
#   'volume_weighted_average': 139.7008,
#   'time': datetime.datetime(2024, 1, 9, 13, 6, tzinfo=<UTC>)},
#  {'open_price': 139.74,
#   'close_price': 139.74,
#   'high_price': 139.74,
#   'low_price': 139.74,
#   'number_of_trades': 11,
#   'volume': 1318,
#   'volume_weighted_average': 139.7402,
#   'time': datetime.datetime(2024, 1, 9, 13, 8, tzinfo=<UTC>)},
#  {'open_price': 139.7791,
#   'close_price': 139.7791,
#   'high_price': 139.7791,
#   'low_price': 139.7791,
#   'number_of_trades': 8,
#   'volume': 518,
#   'volume_weighted_average': 139.777,
#   'time': datetime.datetime(2024, 1, 9, 13, 9, tzinfo=<UTC>)},
#  {'open_price': 139.84,
#   'close_price': 139.79,
#   'high_price': 139.84,
#   'low_price': 139.79,
#   'number_of_trades': 14,
#   'volume': 819,
#   'volume_weighted_average': 139.8196,
#   'time': datetime.datetime(2024, 1, 9, 13, 15, tzinfo=<UTC>)},
#  {'open_price': 139.75,
#   'close_price': 139.75,
#   'high_price': 139.75,
#   'low_price': 139.75,
#   'number_of_trades': 16,
#   'volume': 626,
#   'volume_weighted_average': 139.7356,
#   'time': datetime.datetime(2024, 1, 9, 13, 17, tzinfo=<UTC>)},
#  {'open_price': 139.7,
#   'close_price': 139.7,
#   'high_price': 139.7,
#   'low_price': 139.7,
#   'number_of_trades': 3,
#   'volume': 102,
#   'volume_weighted_average': 139.7004,
#   'time': datetime.datetime(2024, 1, 9, 13, 19, tzinfo=<UTC>)},
#  {'open_price': 139.77,
#   'close_price': 139.77,
#   'high_price': 139.77,
#   'low_price': 139.77,
#   'number_of_trades': 5,
#   'volume': 250,
#   'volume_weighted_average': 139.7637,
#   'time': datetime.datetime(2024, 1, 9, 13, 21, tzinfo=<UTC>)},
#  {'open_price': 139.7001,
#   'close_price': 139.7,
#   'high_price': 139.7001,
#   'low_price': 139.7,
#   'number_of_trades': 22,
#   'volume': 774,
#   'volume_weighted_average': 139.6934,
#   'time': datetime.datetime(2024, 1, 9, 13, 22, tzinfo=<UTC>)},
#  {'open_price': 139.7,
#   'close_price': 139.7,
#   'high_price': 139.7,
#   'low_price': 139.7,
#   'number_of_trades': 15,
#   'volume': 529,
#   'volume_weighted_average': 139.6739,
#   'time': datetime.datetime(2024, 1, 9, 13, 23, tzinfo=<UTC>)},
#  {'open_price': 139.65,
#   'close_price': 139.6898,
#   'high_price': 139.6898,
#   'low_price': 139.65,
#   'number_of_trades': 3,
#   'volume': 862,
#   'volume_weighted_average': 139.681,
#   'time': datetime.datetime(2024, 1, 9, 13, 26, tzinfo=<UTC>)},
#  {'open_price': 139.69,
#   'close_price': 139.69,
#   'high_price': 139.69,
#   'low_price': 139.69,
#   'number_of_trades': 3,
#   'volume': 102,
#   'volume_weighted_average': 139.6898,
#   'time': datetime.datetime(2024, 1, 9, 13, 27, tzinfo=<UTC>)},
#  {'open_price': 139.72,
#   'close_price': 139.72,
#   'high_price': 139.72,
#   'low_price': 139.72,
#   'number_of_trades': 6,
#   'volume': 116,
#   'volume_weighted_average': 139.7195,
#   'time': datetime.datetime(2024, 1, 9, 13, 28, tzinfo=<UTC>)},
#  {'open_price': 139.72,
#   'close_price': 139.72,
#   'high_price': 139.72,
#   'low_price': 139.72,
#   'number_of_trades': 12,
#   'volume': 1204,
#   'volume_weighted_average': 139.7148,
#   'time': datetime.datetime(2024, 1, 9, 13, 29, tzinfo=<UTC>)},
#  {'open_price': 139.66,
#   'close_price': 139.65,
#   'high_price': 139.66,
#   'low_price': 139.65,
#   'number_of_trades': 12,
#   'volume': 661,
#   'volume_weighted_average': 139.6521,
#   'time': datetime.datetime(2024, 1, 9, 13, 30, tzinfo=<UTC>)},
#  {'open_price': 139.63,
#   'close_price': 139.56,
#   'high_price': 139.63,
#   'low_price': 139.56,
#   'number_of_trades': 33,
#   'volume': 1585,
#   'volume_weighted_average': 139.5986,
#   'time': datetime.datetime(2024, 1, 9, 13, 31, tzinfo=<UTC>)},
#  {'open_price': 139.56,
#   'close_price': 139.45,
#   'high_price': 139.56,
#   'low_price': 139.45,
#   'number_of_trades': 37,
#   'volume': 1274,
#   'volume_weighted_average': 139.5186,
#   'time': datetime.datetime(2024, 1, 9, 13, 32, tzinfo=<UTC>)},
#  {'open_price': 139.45,
#   'close_price': 139.57,
#   'high_price': 139.57,
#   'low_price': 139.45,
#   'number_of_trades': 11,
#   'volume': 1155,
#   'volume_weighted_average': 139.5039,
#   'time': datetime.datetime(2024, 1, 9, 13, 33, tzinfo=<UTC>)},
#  {'open_price': 139.46,
#   'close_price': 139.44,
#   'high_price': 139.47,
#   'low_price': 139.44,
#   'number_of_trades': 25,
#   'volume': 1470,
#   'volume_weighted_average': 139.4659,
#   'time': datetime.datetime(2024, 1, 9, 13, 34, tzinfo=<UTC>)},
#  {'open_price': 139.42,
#   'close_price': 139.42,
#   'high_price': 139.42,
#   'low_price': 139.42,
#   'number_of_trades': 23,
#   'volume': 980,
#   'volume_weighted_average': 139.4307,
#   'time': datetime.datetime(2024, 1, 9, 13, 36, tzinfo=<UTC>)},
#  {'open_price': 139.45,
#   'close_price': 139.45,
#   'high_price': 139.45,
#   'low_price': 139.45,
#   'number_of_trades': 7,
#   'volume': 668,
#   'volume_weighted_average': 139.4505,
#   'time': datetime.datetime(2024, 1, 9, 13, 37, tzinfo=<UTC>)},
#  {'open_price': 139.54,
#   'close_price': 139.54,
#   'high_price': 139.54,
#   'low_price': 139.54,
#   'number_of_trades': 21,
#   'volume': 1248,
#   'volume_weighted_average': 139.5362,
#   'time': datetime.datetime(2024, 1, 9, 13, 39, tzinfo=<UTC>)},
#  {'open_price': 139.43,
#   'close_price': 139.39,
#   'high_price': 139.43,
#   'low_price': 139.39,
#   'number_of_trades': 13,
#   'volume': 364,
#   'volume_weighted_average': 139.412,
#   'time': datetime.datetime(2024, 1, 9, 13, 42, tzinfo=<UTC>)},
#  {'open_price': 139.39,
#   'close_price': 139.4,
#   'high_price': 139.4,
#   'low_price': 139.38,
#   'number_of_trades': 13,
#   'volume': 993,
#   'volume_weighted_average': 139.387,
#   'time': datetime.datetime(2024, 1, 9, 13, 43, tzinfo=<UTC>)},
#  {'open_price': 139.38,
#   'close_price': 139.36,
#   'high_price': 139.38,
#   'low_price': 139.36,
#   'number_of_trades': 17,
#   'volume': 543,
#   'volume_weighted_average': 139.3624,
#   'time': datetime.datetime(2024, 1, 9, 13, 44, tzinfo=<UTC>)},
#  {'open_price': 139.33,
#   'close_price': 139.39,
#   'high_price': 139.39,
#   'low_price': 139.31,
#   'number_of_trades': 20,
#   'volume': 764,
#   'volume_weighted_average': 139.3487,
#   'time': datetime.datetime(2024, 1, 9, 13, 45, tzinfo=<UTC>)},
#  {'open_price': 139.39,
#   'close_price': 139.35,
#   'high_price': 139.39,
#   'low_price': 139.33,
#   'number_of_trades': 11,
#   'volume': 636,
#   'volume_weighted_average': 139.3552,
#   'time': datetime.datetime(2024, 1, 9, 13, 46, tzinfo=<UTC>)},
#  {'open_price': 139.3507,
#   'close_price': 139.3507,
#   'high_price': 139.3507,
#   'low_price': 139.3507,
#   'number_of_trades': 7,
#   'volume': 233,
#   'volume_weighted_average': 139.3632,
#   'time': datetime.datetime(2024, 1, 9, 13, 48, tzinfo=<UTC>)},
#  {'open_price': 139.53,
#   'close_price': 139.52,
#   'high_price': 139.53,
#   'low_price': 139.52,
#   'number_of_trades': 13,
#   'volume': 468,
#   'volume_weighted_average': 139.536,
#   'time': datetime.datetime(2024, 1, 9, 13, 51, tzinfo=<UTC>)},
#  {'open_price': 139.5,
#   'close_price': 139.5,
#   'high_price': 139.5,
#   'low_price': 139.5,
#   'number_of_trades': 4,
#   'volume': 201,
#   'volume_weighted_average': 139.5001,
#   'time': datetime.datetime(2024, 1, 9, 13, 53, tzinfo=<UTC>)},
#  {'open_price': 139.57,
#   'close_price': 139.58,
#   'high_price': 139.58,
#   'low_price': 139.57,
#   'number_of_trades': 60,
#   'volume': 2526,
#   'volume_weighted_average': 139.5202,
#   'time': datetime.datetime(2024, 1, 9, 13, 54, tzinfo=<UTC>)},
#  {'open_price': 139.5,
#   'close_price': 139.48,
#   'high_price': 139.5,
#   'low_price': 139.41,
#   'number_of_trades': 35,
#   'volume': 2211,
#   'volume_weighted_average': 139.4636,
#   'time': datetime.datetime(2024, 1, 9, 13, 56, tzinfo=<UTC>)},
#  {'open_price': 139.44,
#   'close_price': 139.44,
#   'high_price': 139.44,
#   'low_price': 139.44,
#   'number_of_trades': 11,
#   'volume': 375,
#   'volume_weighted_average': 139.4519,
#   'time': datetime.datetime(2024, 1, 9, 13, 58, tzinfo=<UTC>)},
#  {'open_price': 139.45,
#   'close_price': 139.45,
#   'high_price': 139.45,
#   'low_price': 139.45,
#   'number_of_trades': 4,
#   'volume': 137,
#   'volume_weighted_average': 139.459,
#   'time': datetime.datetime(2024, 1, 9, 14, 0, tzinfo=<UTC>)},
#  {'open_price': 139.6,
#   'close_price': 139.53,
#   'high_price': 139.64,
#   'low_price': 139.53,
#   'number_of_trades': 36,
#   'volume': 2488,
#   'volume_weighted_average': 139.6074,
#   'time': datetime.datetime(2024, 1, 9, 14, 5, tzinfo=<UTC>)},
#  {'open_price': 139.62,
#   'close_price': 139.62,
#   'high_price': 139.62,
#   'low_price': 139.62,
#   'number_of_trades': 13,
#   'volume': 531,
#   'volume_weighted_average': 139.6207,
#   'time': datetime.datetime(2024, 1, 9, 14, 8, tzinfo=<UTC>)},
#  {'open_price': 139.69,
#   'close_price': 139.69,
#   'high_price': 139.69,
#   'low_price': 139.69,
#   'number_of_trades': 10,
#   'volume': 205,
#   'volume_weighted_average': 139.6698,
#   'time': datetime.datetime(2024, 1, 9, 14, 9, tzinfo=<UTC>)},
#  {'open_price': 139.76,
#   'close_price': 139.76,
#   'high_price': 139.76,
#   'low_price': 139.76,
#   'number_of_trades': 8,
#   'volume': 313,
#   'volume_weighted_average': 139.7601,
#   'time': datetime.datetime(2024, 1, 9, 14, 14, tzinfo=<UTC>)},
#  {'open_price': 139.8,
#   'close_price': 139.8,
#   'high_price': 139.8,
#   'low_price': 139.8,
#   'number_of_trades': 11,
#   'volume': 158,
#   'volume_weighted_average': 139.7977,
#   'time': datetime.datetime(2024, 1, 9, 14, 15, tzinfo=<UTC>)},
#  {'open_price': 139.65,
#   'close_price': 139.7591,
#   'high_price': 139.7591,
#   'low_price': 139.65,
#   'number_of_trades': 20,
#   'volume': 951,
#   'volume_weighted_average': 139.6745,
#   'time': datetime.datetime(2024, 1, 9, 14, 18, tzinfo=<UTC>)},
#  {'open_price': 139.65,
#   'close_price': 139.65,
#   'high_price': 139.65,
#   'low_price': 139.65,
#   'number_of_trades': 12,
#   'volume': 347,
#   'volume_weighted_average': 139.6883,
#   'time': datetime.datetime(2024, 1, 9, 14, 20, tzinfo=<UTC>)},
#  {'open_price': 139.74,
#   'close_price': 139.74,
#   'high_price': 139.74,
#   'low_price': 139.74,
#   'number_of_trades': 11,
#   'volume': 1001,
#   'volume_weighted_average': 139.7356,
#   'time': datetime.datetime(2024, 1, 9, 14, 21, tzinfo=<UTC>)},
#  {'open_price': 139.67,
#   'close_price': 139.94,
#   'high_price': 139.96,
#   'low_price': 139.66,
#   'number_of_trades': 111,
#   'volume': 7449,
#   'volume_weighted_average': 139.8056,
#   'time': datetime.datetime(2024, 1, 9, 14, 25, tzinfo=<UTC>)},
#  {'open_price': 139.94,
#   'close_price': 140.1,
#   'high_price': 140.24,
#   'low_price': 139.93,
#   'number_of_trades': 110,
#   'volume': 6845,
#   'volume_weighted_average': 140.0366,
#   'time': datetime.datetime(2024, 1, 9, 14, 26, tzinfo=<UTC>)},
#  {'open_price': 140.09,
#   'close_price': 140,
#   'high_price': 140.24,
#   'low_price': 139.76,
#   'number_of_trades': 133,
#   'volume': 8143,
#   'volume_weighted_average': 140.0745,
#   'time': datetime.datetime(2024, 1, 9, 14, 27, tzinfo=<UTC>)},
#  {'open_price': 140,
#   'close_price': 140,
#   'high_price': 140,
#   'low_price': 140,
#   'number_of_trades': 6,
#   'volume': 186,
#   'volume_weighted_average': 140.0267,
#   'time': datetime.datetime(2024, 1, 9, 14, 28, tzinfo=<UTC>)},
#  {'open_price': 140,
#   'close_price': 140.09,
#   'high_price': 140.1,
#   'low_price': 139.94,
#   'number_of_trades': 97,
#   'volume': 7015,
#   'volume_weighted_average': 140.0347,
#   'time': datetime.datetime(2024, 1, 9, 14, 29, tzinfo=<UTC>)},
#  {'open_price': 140.06,
#   'close_price': 139.81,
#   'high_price': 140.56,
#   'low_price': 139.79,
#   'number_of_trades': 3555,
#   'volume': 303522,
#   'volume_weighted_average': 140.1308,
#   'time': datetime.datetime(2024, 1, 9, 14, 30, tzinfo=<UTC>)},
#  {'open_price': 139.84,
#   'close_price': 140.1095,
#   'high_price': 140.28,
#   'low_price': 139.84,
#   'number_of_trades': 1554,
#   'volume': 100351,
#   'volume_weighted_average': 140.1046,
#   'time': datetime.datetime(2024, 1, 9, 14, 31, tzinfo=<UTC>)},
#  {'open_price': 140.12,
#   'close_price': 140.67,
#   'high_price': 140.86,
#   'low_price': 140.1,
#   'number_of_trades': 2419,
#   'volume': 156134,
#   'volume_weighted_average': 140.67,
#   'time': datetime.datetime(2024, 1, 9, 14, 32, tzinfo=<UTC>)},
#  {'open_price': 140.61,
#   'close_price': 140.59,
#   'high_price': 140.7667,
#   'low_price': 140.44,
#   'number_of_trades': 1300,
#   'volume': 96431,
#   'volume_weighted_average': 140.6272,
#   'time': datetime.datetime(2024, 1, 9, 14, 33, tzinfo=<UTC>)},
#  {'open_price': 140.59,
#   'close_price': 140.705,
#   'high_price': 140.7931,
#   'low_price': 140.57,
#   'number_of_trades': 1442,
#   'volume': 86171,
#   'volume_weighted_average': 140.6995,
#   'time': datetime.datetime(2024, 1, 9, 14, 34, tzinfo=<UTC>)},
#  {'open_price': 140.7,
#   'close_price': 140.35,
#   'high_price': 140.71,
#   'low_price': 140.34,
#   'number_of_trades': 1212,
#   'volume': 76141,
#   'volume_weighted_average': 140.5601,
#   'time': datetime.datetime(2024, 1, 9, 14, 35, tzinfo=<UTC>)},
#  {'open_price': 140.37,
#   'close_price': 140.84,
#   'high_price': 140.84,
#   'low_price': 140.37,
#   'number_of_trades': 1276,
#   'volume': 108890,
#   'volume_weighted_average': 140.6549,
#   'time': datetime.datetime(2024, 1, 9, 14, 36, tzinfo=<UTC>)},
#  {'open_price': 140.86,
#   'close_price': 140.94,
#   'high_price': 140.95,
#   'low_price': 140.79,
#   'number_of_trades': 1114,
#   'volume': 88338,
#   'volume_weighted_average': 140.8703,
#   'time': datetime.datetime(2024, 1, 9, 14, 37, tzinfo=<UTC>)},
#  {'open_price': 140.93,
#   'close_price': 140.81,
#   'high_price': 140.93,
#   'low_price': 140.7169,
#   'number_of_trades': 1173,
#   'volume': 87069,
#   'volume_weighted_average': 140.8167,
#   'time': datetime.datetime(2024, 1, 9, 14, 38, tzinfo=<UTC>)},
#  {'open_price': 140.785,
#   'close_price': 140.91,
#   'high_price': 141.015,
#   'low_price': 140.785,
#   'number_of_trades': 1354,
#   'volume': 102605,
#   'volume_weighted_average': 140.9587,
#   'time': datetime.datetime(2024, 1, 9, 14, 39, tzinfo=<UTC>)},
#  {'open_price': 140.9169,
#   'close_price': 140.9046,
#   'high_price': 141.03,
#   'low_price': 140.82,
#   'number_of_trades': 1187,
#   'volume': 86518,
#   'volume_weighted_average': 140.9424,
#   'time': datetime.datetime(2024, 1, 9, 14, 40, tzinfo=<UTC>)},
#  {'open_price': 140.92,
#   'close_price': 141.31,
#   'high_price': 141.31,
#   'low_price': 140.92,
#   'number_of_trades': 1146,
#   'volume': 109763,
#   'volume_weighted_average': 141.1479,
#   'time': datetime.datetime(2024, 1, 9, 14, 41, tzinfo=<UTC>)},
#  {'open_price': 141.32,
#   'close_price': 141.175,
#   'high_price': 141.43,
#   'low_price': 141.16,
#   'number_of_trades': 1300,
#   'volume': 93816,
#   'volume_weighted_average': 141.3138,
#   'time': datetime.datetime(2024, 1, 9, 14, 42, tzinfo=<UTC>)},
#  {'open_price': 141.17,
#   'close_price': 141.02,
#   'high_price': 141.22,
#   'low_price': 140.92,
#   'number_of_trades': 1327,
#   'volume': 83648,
#   'volume_weighted_average': 141.096,
#   'time': datetime.datetime(2024, 1, 9, 14, 43, tzinfo=<UTC>)},
#  {'open_price': 141,
#   'close_price': 141.165,
#   'high_price': 141.22,
#   'low_price': 140.9,
#   'number_of_trades': 1321,
#   'volume': 78142,
#   'volume_weighted_average': 141.0527,
#   'time': datetime.datetime(2024, 1, 9, 14, 44, tzinfo=<UTC>)},
#  {'open_price': 141.195,
#   'close_price': 141.165,
#   'high_price': 141.27,
#   'low_price': 141.11,
#   'number_of_trades': 1303,
#   'volume': 83311,
#   'volume_weighted_average': 141.194,
#   'time': datetime.datetime(2024, 1, 9, 14, 45, tzinfo=<UTC>)},
#  {'open_price': 141.17,
#   'close_price': 141.005,
#   'high_price': 141.1753,
#   'low_price': 140.98,
#   'number_of_trades': 879,
#   'volume': 50945,
#   'volume_weighted_average': 141.0718,
#   'time': datetime.datetime(2024, 1, 9, 14, 46, tzinfo=<UTC>)},
#  {'open_price': 141,
#   'close_price': 140.8362,
#   'high_price': 141,
#   'low_price': 140.7,
#   'number_of_trades': 1123,
#   'volume': 74436,
#   'volume_weighted_average': 140.8069,
#   'time': datetime.datetime(2024, 1, 9, 14, 47, tzinfo=<UTC>)},
#  {'open_price': 140.8568,
#   'close_price': 140.985,
#   'high_price': 141.05,
#   'low_price': 140.8431,
#   'number_of_trades': 1015,
#   'volume': 88618,
#   'volume_weighted_average': 140.9786,
#   'time': datetime.datetime(2024, 1, 9, 14, 48, tzinfo=<UTC>)},
#  {'open_price': 140.98,
#   'close_price': 140.73,
#   'high_price': 140.98,
#   'low_price': 140.7122,
#   'number_of_trades': 852,
#   'volume': 46920,
#   'volume_weighted_average': 140.837,
#   'time': datetime.datetime(2024, 1, 9, 14, 49, tzinfo=<UTC>)},
#  {'open_price': 140.72,
#   'close_price': 140.86,
#   'high_price': 140.9,
#   'low_price': 140.61,
#   'number_of_trades': 994,
#   'volume': 55028,
#   'volume_weighted_average': 140.7175,
#   'time': datetime.datetime(2024, 1, 9, 14, 50, tzinfo=<UTC>)},
#  {'open_price': 140.85,
#   'close_price': 140.97,
#   'high_price': 140.9877,
#   'low_price': 140.82,
#   'number_of_trades': 566,
#   'volume': 30854,
#   'volume_weighted_average': 140.9249,
#   'time': datetime.datetime(2024, 1, 9, 14, 51, tzinfo=<UTC>)},
#  {'open_price': 140.96,
#   'close_price': 141.0417,
#   'high_price': 141.06,
#   'low_price': 140.925,
#   'number_of_trades': 712,
#   'volume': 43534,
#   'volume_weighted_average': 140.9997,
#   'time': datetime.datetime(2024, 1, 9, 14, 52, tzinfo=<UTC>)},
#  {'open_price': 141.05,
#   'close_price': 140.88,
#   'high_price': 141.065,
#   'low_price': 140.87,
#   'number_of_trades': 625,
#   'volume': 35979,
#   'volume_weighted_average': 140.9786,
#   'time': datetime.datetime(2024, 1, 9, 14, 53, tzinfo=<UTC>)},
#  {'open_price': 140.88,
#   'close_price': 140.752,
#   'high_price': 140.91,
#   'low_price': 140.73,
#   'number_of_trades': 562,
#   'volume': 33060,
#   'volume_weighted_average': 140.8113,
#   'time': datetime.datetime(2024, 1, 9, 14, 54, tzinfo=<UTC>)},
#  {'open_price': 140.75,
#   'close_price': 140.9493,
#   'high_price': 140.98,
#   'low_price': 140.61,
#   'number_of_trades': 707,
#   'volume': 60829,
#   'volume_weighted_average': 140.8101,
#   'time': datetime.datetime(2024, 1, 9, 14, 55, tzinfo=<UTC>)},
#  {'open_price': 140.9483,
#   'close_price': 141.005,
#   'high_price': 141.01,
#   'low_price': 140.87,
#   'number_of_trades': 881,
#   'volume': 65828,
#   'volume_weighted_average': 140.9734,
#   'time': datetime.datetime(2024, 1, 9, 14, 56, tzinfo=<UTC>)},
#  {'open_price': 140.99,
#   'close_price': 141.1016,
#   'high_price': 141.11,
#   'low_price': 140.97,
#   'number_of_trades': 1160,
#   'volume': 84322,
#   'volume_weighted_average': 141.0219,
#   'time': datetime.datetime(2024, 1, 9, 14, 57, tzinfo=<UTC>)},
#  {'open_price': 141.11,
#   'close_price': 141.12,
#   'high_price': 141.21,
#   'low_price': 141.09,
#   'number_of_trades': 671,
#   'volume': 50568,
#   'volume_weighted_average': 141.15,
#   'time': datetime.datetime(2024, 1, 9, 14, 58, tzinfo=<UTC>)},
#  {'open_price': 141.14,
#   'close_price': 141.11,
#   'high_price': 141.1801,
#   'low_price': 141.06,
#   'number_of_trades': 628,
#   'volume': 51856,
#   'volume_weighted_average': 141.1183,
#   'time': datetime.datetime(2024, 1, 9, 14, 59, tzinfo=<UTC>)},
#  {'open_price': 141.12,
#   'close_price': 140.99,
#   'high_price': 141.13,
#   'low_price': 140.9715,
#   'number_of_trades': 1017,
#   'volume': 69602,
#   'volume_weighted_average': 141.0494,
#   'time': datetime.datetime(2024, 1, 9, 15, 0, tzinfo=<UTC>)},
#  {'open_price': 140.98,
#   'close_price': 141.07,
#   'high_price': 141.11,
#   'low_price': 140.88,
#   'number_of_trades': 903,
#   'volume': 92395,
#   'volume_weighted_average': 141.0414,
#   'time': datetime.datetime(2024, 1, 9, 15, 1, tzinfo=<UTC>)},
#  {'open_price': 141.06,
#   'close_price': 141.205,
#   'high_price': 141.205,
#   'low_price': 141.02,
#   'number_of_trades': 986,
#   'volume': 77501,
#   'volume_weighted_average': 141.1115,
#   'time': datetime.datetime(2024, 1, 9, 15, 2, tzinfo=<UTC>)},
#  {'open_price': 141.225,
#   'close_price': 141.05,
#   'high_price': 141.225,
#   'low_price': 141.0001,
#   'number_of_trades': 618,
#   'volume': 38462,
#   'volume_weighted_average': 141.0958,
#   'time': datetime.datetime(2024, 1, 9, 15, 3, tzinfo=<UTC>)},
#  {'open_price': 141.03,
#   'close_price': 141.07,
#   'high_price': 141.1699,
#   'low_price': 140.99,
#   'number_of_trades': 493,
#   'volume': 28994,
#   'volume_weighted_average': 141.0821,
#   'time': datetime.datetime(2024, 1, 9, 15, 4, tzinfo=<UTC>)},
#  {'open_price': 141.08,
#   'close_price': 140.99,
#   'high_price': 141.14,
#   'low_price': 140.98,
#   'number_of_trades': 634,
#   'volume': 36950,
#   'volume_weighted_average': 141.0375,
#   'time': datetime.datetime(2024, 1, 9, 15, 5, tzinfo=<UTC>)},
#  {'open_price': 140.98,
#   'close_price': 141.04,
#   'high_price': 141.07,
#   'low_price': 140.925,
#   'number_of_trades': 645,
#   'volume': 49308,
#   'volume_weighted_average': 141.0198,
#   'time': datetime.datetime(2024, 1, 9, 15, 6, tzinfo=<UTC>)},
#  {'open_price': 141.03,
#   'close_price': 141.08,
#   'high_price': 141.135,
#   'low_price': 141.01,
#   'number_of_trades': 768,
#   'volume': 75875,
#   'volume_weighted_average': 141.0598,
#   'time': datetime.datetime(2024, 1, 9, 15, 7, tzinfo=<UTC>)},
#  {'open_price': 141.075,
#   'close_price': 141.19,
#   'high_price': 141.2,
#   'low_price': 141.075,
#   'number_of_trades': 799,
#   'volume': 89258,
#   'volume_weighted_average': 141.1418,
#   'time': datetime.datetime(2024, 1, 9, 15, 8, tzinfo=<UTC>)},
#  {'open_price': 141.19,
#   'close_price': 141.2,
#   'high_price': 141.21,
#   'low_price': 141.1101,
#   'number_of_trades': 833,
#   'volume': 50969,
#   'volume_weighted_average': 141.1895,
#   'time': datetime.datetime(2024, 1, 9, 15, 9, tzinfo=<UTC>)},
#  {'open_price': 141.205,
#   'close_price': 141.381,
#   'high_price': 141.3888,
#   'low_price': 141.2,
#   'number_of_trades': 1330,
#   'volume': 110450,
#   'volume_weighted_average': 141.27,
#   'time': datetime.datetime(2024, 1, 9, 15, 10, tzinfo=<UTC>)},
#  {'open_price': 141.38,
#   'close_price': 141.4,
#   'high_price': 141.4099,
#   'low_price': 141.3293,
#   'number_of_trades': 578,
#   'volume': 30067,
#   'volume_weighted_average': 141.3828,
#   'time': datetime.datetime(2024, 1, 9, 15, 11, tzinfo=<UTC>)},
#  {'open_price': 141.39,
#   'close_price': 141.37,
#   'high_price': 141.39,
#   'low_price': 141.31,
#   'number_of_trades': 541,
#   'volume': 24165,
#   'volume_weighted_average': 141.3407,
#   'time': datetime.datetime(2024, 1, 9, 15, 12, tzinfo=<UTC>)},
#  {'open_price': 141.36,
#   'close_price': 141.38,
#   'high_price': 141.41,
#   'low_price': 141.34,
#   'number_of_trades': 809,
#   'volume': 55943,
#   'volume_weighted_average': 141.3884,
#   'time': datetime.datetime(2024, 1, 9, 15, 13, tzinfo=<UTC>)},
#  {'open_price': 141.38,
#   'close_price': 141.355,
#   'high_price': 141.43,
#   'low_price': 141.325,
#   'number_of_trades': 967,
#   'volume': 62298,
#   'volume_weighted_average': 141.392,
#   'time': datetime.datetime(2024, 1, 9, 15, 14, tzinfo=<UTC>)},
#  {'open_price': 141.36,
#   'close_price': 141.4,
#   'high_price': 141.4101,
#   'low_price': 141.335,
#   'number_of_trades': 732,
#   'volume': 40614,
#   'volume_weighted_average': 141.3847,
#   'time': datetime.datetime(2024, 1, 9, 15, 15, tzinfo=<UTC>)},
#  {'open_price': 141.39,
#   'close_price': 141.51,
#   'high_price': 141.6,
#   'low_price': 141.39,
#   'number_of_trades': 1524,
#   'volume': 126589,
#   'volume_weighted_average': 141.5049,
#   'time': datetime.datetime(2024, 1, 9, 15, 16, tzinfo=<UTC>)},
#  {'open_price': 141.5,
#   'close_price': 141.36,
#   'high_price': 141.56,
#   'low_price': 141.345,
#   'number_of_trades': 950,
#   'volume': 96988,
#   'volume_weighted_average': 141.4817,
#   'time': datetime.datetime(2024, 1, 9, 15, 17, tzinfo=<UTC>)},
#  {'open_price': 141.36,
#   'close_price': 141.315,
#   'high_price': 141.5797,
#   'low_price': 141.28,
#   'number_of_trades': 1022,
#   'volume': 99696,
#   'volume_weighted_average': 141.3974,
#   'time': datetime.datetime(2024, 1, 9, 15, 18, tzinfo=<UTC>)},
#  {'open_price': 141.32,
#   'close_price': 141.47,
#   'high_price': 141.5,
#   'low_price': 141.32,
#   'number_of_trades': 635,
#   'volume': 65455,
#   'volume_weighted_average': 141.4406,
#   'time': datetime.datetime(2024, 1, 9, 15, 19, tzinfo=<UTC>)},
#  {'open_price': 141.465,
#   'close_price': 141.47,
#   'high_price': 141.52,
#   'low_price': 141.46,
#   'number_of_trades': 458,
#   'volume': 27970,
#   'volume_weighted_average': 141.4899,
#   'time': datetime.datetime(2024, 1, 9, 15, 20, tzinfo=<UTC>)},
#  {'open_price': 141.49,
#   'close_price': 141.56,
#   'high_price': 141.57,
#   'low_price': 141.46,
#   'number_of_trades': 558,
#   'volume': 51179,
#   'volume_weighted_average': 141.5142,
#   'time': datetime.datetime(2024, 1, 9, 15, 21, tzinfo=<UTC>)},
#  {'open_price': 141.555,
#   'close_price': 141.43,
#   'high_price': 141.58,
#   'low_price': 141.42,
#   'number_of_trades': 721,
#   'volume': 66706,
#   'volume_weighted_average': 141.5258,
#   'time': datetime.datetime(2024, 1, 9, 15, 22, tzinfo=<UTC>)},
#  {'open_price': 141.44,
#   'close_price': 141.43,
#   'high_price': 141.48,
#   'low_price': 141.43,
#   'number_of_trades': 761,
#   'volume': 62641,
#   'volume_weighted_average': 141.4564,
#   'time': datetime.datetime(2024, 1, 9, 15, 23, tzinfo=<UTC>)},
#  {'open_price': 141.44,
#   'close_price': 141.49,
#   'high_price': 141.49,
#   'low_price': 141.37,
#   'number_of_trades': 876,
#   'volume': 86111,
#   'volume_weighted_average': 141.406,
#   'time': datetime.datetime(2024, 1, 9, 15, 24, tzinfo=<UTC>)},
#  {'open_price': 141.48,
#   'close_price': 141.375,
#   'high_price': 141.5,
#   'low_price': 141.365,
#   'number_of_trades': 763,
#   'volume': 86191,
#   'volume_weighted_average': 141.4188,
#   'time': datetime.datetime(2024, 1, 9, 15, 25, tzinfo=<UTC>)},
#  {'open_price': 141.37,
#   'close_price': 141.375,
#   'high_price': 141.41,
#   'low_price': 141.305,
#   'number_of_trades': 712,
#   'volume': 38818,
#   'volume_weighted_average': 141.3582,
#   'time': datetime.datetime(2024, 1, 9, 15, 26, tzinfo=<UTC>)},
#  {'open_price': 141.3692,
#   'close_price': 141.27,
#   'high_price': 141.395,
#   'low_price': 141.24,
#   'number_of_trades': 911,
#   'volume': 61126,
#   'volume_weighted_average': 141.2974,
#   'time': datetime.datetime(2024, 1, 9, 15, 27, tzinfo=<UTC>)},
#  {'open_price': 141.26,
#   'close_price': 141.31,
#   'high_price': 141.32,
#   'low_price': 141.22,
#   'number_of_trades': 702,
#   'volume': 39271,
#   'volume_weighted_average': 141.2706,
#   'time': datetime.datetime(2024, 1, 9, 15, 28, tzinfo=<UTC>)},
#  {'open_price': 141.315,
#   'close_price': 141.23,
#   'high_price': 141.315,
#   'low_price': 141.195,
#   'number_of_trades': 813,
#   'volume': 47357,
#   'volume_weighted_average': 141.236,
#   'time': datetime.datetime(2024, 1, 9, 15, 29, tzinfo=<UTC>)},
#  {'open_price': 141.235,
#   'close_price': 141.0707,
#   'high_price': 141.25,
#   'low_price': 141.0707,
#   'number_of_trades': 981,
#   'volume': 63118,
#   'volume_weighted_average': 141.1431,
#   'time': datetime.datetime(2024, 1, 9, 15, 30, tzinfo=<UTC>)},
#  {'open_price': 141.1,
#   'close_price': 141.07,
#   'high_price': 141.18,
#   'low_price': 141.035,
#   'number_of_trades': 752,
#   'volume': 46455,
#   'volume_weighted_average': 141.1215,
#   'time': datetime.datetime(2024, 1, 9, 15, 31, tzinfo=<UTC>)},
#  {'open_price': 141.055,
#   'close_price': 140.88,
#   'high_price': 141.055,
#   'low_price': 140.85,
#   'number_of_trades': 887,
#   'volume': 58793,
#   'volume_weighted_average': 140.9454,
#   'time': datetime.datetime(2024, 1, 9, 15, 32, tzinfo=<UTC>)},
#  {'open_price': 140.871,
#   'close_price': 141.1,
#   'high_price': 141.115,
#   'low_price': 140.86,
#   'number_of_trades': 602,
#   'volume': 29548,
#   'volume_weighted_average': 140.9735,
#   'time': datetime.datetime(2024, 1, 9, 15, 33, tzinfo=<UTC>)},
#  {'open_price': 141.1,
#   'close_price': 141.08,
#   'high_price': 141.17,
#   'low_price': 141.08,
#   'number_of_trades': 563,
#   'volume': 35875,
#   'volume_weighted_average': 141.1237,
#   'time': datetime.datetime(2024, 1, 9, 15, 34, tzinfo=<UTC>)},
#  {'open_price': 141.08,
#   'close_price': 141.15,
#   'high_price': 141.15,
#   'low_price': 140.99,
#   'number_of_trades': 390,
#   'volume': 35609,
#   'volume_weighted_average': 141.0813,
#   'time': datetime.datetime(2024, 1, 9, 15, 35, tzinfo=<UTC>)},
#  {'open_price': 141.15,
#   'close_price': 141.25,
#   'high_price': 141.27,
#   'low_price': 141.145,
#   'number_of_trades': 475,
#   'volume': 38858,
#   'volume_weighted_average': 141.1879,
#   'time': datetime.datetime(2024, 1, 9, 15, 36, tzinfo=<UTC>)},
#  {'open_price': 141.26,
#   'close_price': 141.291,
#   'high_price': 141.355,
#   'low_price': 141.26,
#   'number_of_trades': 422,
#   'volume': 28014,
#   'volume_weighted_average': 141.3132,
#   'time': datetime.datetime(2024, 1, 9, 15, 37, tzinfo=<UTC>)},
#  {'open_price': 141.2937,
#   'close_price': 141.275,
#   'high_price': 141.35,
#   'low_price': 141.27,
#   'number_of_trades': 587,
#   'volume': 28508,
#   'volume_weighted_average': 141.3069,
#   'time': datetime.datetime(2024, 1, 9, 15, 38, tzinfo=<UTC>)},
#  {'open_price': 141.26,
#   'close_price': 141.395,
#   'high_price': 141.4,
#   'low_price': 141.26,
#   'number_of_trades': 490,
#   'volume': 31002,
#   'volume_weighted_average': 141.3467,
#   'time': datetime.datetime(2024, 1, 9, 15, 39, tzinfo=<UTC>)},
#  {'open_price': 141.4,
#   'close_price': 141.3701,
#   'high_price': 141.4,
#   'low_price': 141.33,
#   'number_of_trades': 540,
#   'volume': 31904,
#   'volume_weighted_average': 141.3706,
#   'time': datetime.datetime(2024, 1, 9, 15, 40, tzinfo=<UTC>)},
#  {'open_price': 141.37,
#   'close_price': 141.345,
#   'high_price': 141.37,
#   'low_price': 141.285,
#   'number_of_trades': 406,
#   'volume': 16607,
#   'volume_weighted_average': 141.3331,
#   'time': datetime.datetime(2024, 1, 9, 15, 41, tzinfo=<UTC>)},
#  {'open_price': 141.3495,
#   'close_price': 141.355,
#   'high_price': 141.37,
#   'low_price': 141.32,
#   'number_of_trades': 527,
#   'volume': 28757,
#   'volume_weighted_average': 141.3518,
#   'time': datetime.datetime(2024, 1, 9, 15, 42, tzinfo=<UTC>)},
#  {'open_price': 141.355,
#   'close_price': 141.395,
#   'high_price': 141.395,
#   'low_price': 141.305,
#   'number_of_trades': 574,
#   'volume': 36230,
#   'volume_weighted_average': 141.3555,
#   'time': datetime.datetime(2024, 1, 9, 15, 43, tzinfo=<UTC>)},
#  {'open_price': 141.395,
#   'close_price': 141.445,
#   'high_price': 141.4501,
#   'low_price': 141.375,
#   'number_of_trades': 1202,
#   'volume': 106336,
#   'volume_weighted_average': 141.4093,
#   'time': datetime.datetime(2024, 1, 9, 15, 44, tzinfo=<UTC>)},
#  {'open_price': 141.44,
#   'close_price': 141.285,
#   'high_price': 141.5,
#   'low_price': 141.28,
#   'number_of_trades': 1005,
#   'volume': 91478,
#   'volume_weighted_average': 141.4336,
#   'time': datetime.datetime(2024, 1, 9, 15, 45, tzinfo=<UTC>)},
#  {'open_price': 141.27,
#   'close_price': 141.33,
#   'high_price': 141.3554,
#   'low_price': 141.26,
#   'number_of_trades': 505,
#   'volume': 31439,
#   'volume_weighted_average': 141.3055,
#   'time': datetime.datetime(2024, 1, 9, 15, 46, tzinfo=<UTC>)},
#  {'open_price': 141.33,
#   'close_price': 141.43,
#   'high_price': 141.45,
#   'low_price': 141.325,
#   'number_of_trades': 474,
#   'volume': 33825,
#   'volume_weighted_average': 141.3892,
#   'time': datetime.datetime(2024, 1, 9, 15, 47, tzinfo=<UTC>)},
#  {'open_price': 141.44,
#   'close_price': 141.445,
#   'high_price': 141.45,
#   'low_price': 141.39,
#   'number_of_trades': 423,
#   'volume': 31221,
#   'volume_weighted_average': 141.4215,
#   'time': datetime.datetime(2024, 1, 9, 15, 48, tzinfo=<UTC>)},
#  {'open_price': 141.44,
#   'close_price': 141.5175,
#   'high_price': 141.545,
#   'low_price': 141.4224,
#   'number_of_trades': 545,
#   'volume': 46260,
#   'volume_weighted_average': 141.4728,
#   'time': datetime.datetime(2024, 1, 9, 15, 49, tzinfo=<UTC>)},
#  {'open_price': 141.51,
#   'close_price': 141.53,
#   'high_price': 141.565,
#   'low_price': 141.47,
#   'number_of_trades': 434,
#   'volume': 27058,
#   'volume_weighted_average': 141.5257,
#   'time': datetime.datetime(2024, 1, 9, 15, 50, tzinfo=<UTC>)},
#  {'open_price': 141.53,
#   'close_price': 141.58,
#   'high_price': 141.6,
#   'low_price': 141.525,
#   'number_of_trades': 496,
#   'volume': 27729,
#   'volume_weighted_average': 141.5708,
#   'time': datetime.datetime(2024, 1, 9, 15, 51, tzinfo=<UTC>)},
#  {'open_price': 141.57,
#   'close_price': 141.445,
#   'high_price': 141.57,
#   'low_price': 141.445,
#   'number_of_trades': 494,
#   'volume': 36459,
#   'volume_weighted_average': 141.4974,
#   'time': datetime.datetime(2024, 1, 9, 15, 52, tzinfo=<UTC>)},
#  {'open_price': 141.43,
#   'close_price': 141.55,
#   'high_price': 141.55,
#   'low_price': 141.43,
#   'number_of_trades': 370,
#   'volume': 24048,
#   'volume_weighted_average': 141.4868,
#   'time': datetime.datetime(2024, 1, 9, 15, 53, tzinfo=<UTC>)},
#  {'open_price': 141.555,
#   'close_price': 141.57,
#   'high_price': 141.57,
#   'low_price': 141.47,
#   'number_of_trades': 625,
#   'volume': 42118,
#   'volume_weighted_average': 141.5342,
#   'time': datetime.datetime(2024, 1, 9, 15, 54, tzinfo=<UTC>)},
#  {'open_price': 141.565,
#   'close_price': 141.615,
#   'high_price': 141.63,
#   'low_price': 141.54,
#   'number_of_trades': 569,
#   'volume': 48419,
#   'volume_weighted_average': 141.5972,
#   'time': datetime.datetime(2024, 1, 9, 15, 55, tzinfo=<UTC>)},
#  {'open_price': 141.61,
#   'close_price': 141.53,
#   'high_price': 141.61,
#   'low_price': 141.465,
#   'number_of_trades': 518,
#   'volume': 39270,
#   'volume_weighted_average': 141.5476,
#   'time': datetime.datetime(2024, 1, 9, 15, 56, tzinfo=<UTC>)},
#  {'open_price': 141.54,
#   'close_price': 141.47,
#   'high_price': 141.555,
#   'low_price': 141.44,
#   'number_of_trades': 407,
#   'volume': 24302,
#   'volume_weighted_average': 141.4881,
#   'time': datetime.datetime(2024, 1, 9, 15, 57, tzinfo=<UTC>)},
#  {'open_price': 141.45,
#   'close_price': 141.36,
#   'high_price': 141.475,
#   'low_price': 141.3263,
#   'number_of_trades': 486,
#   'volume': 38496,
#   'volume_weighted_average': 141.3924,
#   'time': datetime.datetime(2024, 1, 9, 15, 58, tzinfo=<UTC>)},
#  {'open_price': 141.365,
#   'close_price': 141.4105,
#   'high_price': 141.415,
#   'low_price': 141.345,
#   'number_of_trades': 379,
#   'volume': 25836,
#   'volume_weighted_average': 141.3772,
#   'time': datetime.datetime(2024, 1, 9, 15, 59, tzinfo=<UTC>)},
#  {'open_price': 141.41,
#   'close_price': 141.46,
#   'high_price': 141.49,
#   'low_price': 141.405,
#   'number_of_trades': 489,
#   'volume': 36468,
#   'volume_weighted_average': 141.4446,
#   'time': datetime.datetime(2024, 1, 9, 16, 0, tzinfo=<UTC>)},
#  {'open_price': 141.47,
#   'close_price': 141.57,
#   'high_price': 141.57,
#   'low_price': 141.411,
#   'number_of_trades': 626,
#   'volume': 49243,
#   'volume_weighted_average': 141.4583,
#   'time': datetime.datetime(2024, 1, 9, 16, 1, tzinfo=<UTC>)},
#  {'open_price': 141.5672,
#   'close_price': 141.6,
#   'high_price': 141.6199,
#   'low_price': 141.545,
#   'number_of_trades': 517,
#   'volume': 51196,
#   'volume_weighted_average': 141.5813,
#   'time': datetime.datetime(2024, 1, 9, 16, 2, tzinfo=<UTC>)},
#  {'open_price': 141.59,
#   'close_price': 141.59,
#   'high_price': 141.63,
#   'low_price': 141.56,
#   'number_of_trades': 415,
#   'volume': 31581,
#   'volume_weighted_average': 141.5989,
#   'time': datetime.datetime(2024, 1, 9, 16, 3, tzinfo=<UTC>)},
#  {'open_price': 141.58,
#   'close_price': 141.59,
#   'high_price': 141.61,
#   'low_price': 141.56,
#   'number_of_trades': 495,
#   'volume': 35043,
#   'volume_weighted_average': 141.5832,
#   'time': datetime.datetime(2024, 1, 9, 16, 4, tzinfo=<UTC>)},
#  {'open_price': 141.58,
#   'close_price': 141.4915,
#   'high_price': 141.6143,
#   'low_price': 141.45,
#   'number_of_trades': 451,
#   'volume': 35793,
#   'volume_weighted_average': 141.5156,
#   'time': datetime.datetime(2024, 1, 9, 16, 5, tzinfo=<UTC>)},
#  {'open_price': 141.5,
#   'close_price': 141.605,
#   'high_price': 141.615,
# ...
#   'volume': 513,
#   'volume_weighted_average': 142.55,
#   'time': datetime.datetime(2024, 1, 9, 21, 11, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.55,
#   'high_price': 142.55,
#   'low_price': 142.55,
#   'number_of_trades': 15,
#   'volume': 817,
#   'volume_weighted_average': 142.5495,
#   'time': datetime.datetime(2024, 1, 9, 21, 12, tzinfo=<UTC>)},
#  {'open_price': 142.56,
#   'close_price': 142.56,
#   'high_price': 142.56,
#   'low_price': 142.56,
#   'number_of_trades': 3,
#   'volume': 301,
#   'volume_weighted_average': 142.5583,
#   'time': datetime.datetime(2024, 1, 9, 21, 14, tzinfo=<UTC>)},
#  {'open_price': 142.54,
#   'close_price': 142.54,
#   'high_price': 142.54,
#   'low_price': 142.54,
#   'number_of_trades': 10,
#   'volume': 1026,
#   'volume_weighted_average': 142.5396,
#   'time': datetime.datetime(2024, 1, 9, 21, 15, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.55,
#   'high_price': 142.55,
#   'low_price': 142.55,
#   'number_of_trades': 7,
#   'volume': 308,
#   'volume_weighted_average': 142.5494,
#   'time': datetime.datetime(2024, 1, 9, 21, 18, tzinfo=<UTC>)},
#  {'open_price': 142.56,
#   'close_price': 142.56,
#   'high_price': 142.56,
#   'low_price': 142.55,
#   'number_of_trades': 9,
#   'volume': 6633,
#   'volume_weighted_average': 142.5595,
#   'time': datetime.datetime(2024, 1, 9, 21, 20, tzinfo=<UTC>)},
#  {'open_price': 142.5597,
#   'close_price': 142.5597,
#   'high_price': 142.5597,
#   'low_price': 142.5597,
#   'number_of_trades': 8,
#   'volume': 249,
#   'volume_weighted_average': 142.558,
#   'time': datetime.datetime(2024, 1, 9, 21, 22, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.55,
#   'high_price': 142.55,
#   'low_price': 142.55,
#   'number_of_trades': 5,
#   'volume': 327,
#   'volume_weighted_average': 142.5504,
#   'time': datetime.datetime(2024, 1, 9, 21, 24, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.52,
#   'high_price': 142.55,
#   'low_price': 142.52,
#   'number_of_trades': 11,
#   'volume': 641,
#   'volume_weighted_average': 142.5376,
#   'time': datetime.datetime(2024, 1, 9, 21, 25, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 9,
#   'volume': 160,
#   'volume_weighted_average': 142.5165,
#   'time': datetime.datetime(2024, 1, 9, 21, 28, tzinfo=<UTC>)},
#  {'open_price': 142.51,
#   'close_price': 142.51,
#   'high_price': 142.51,
#   'low_price': 142.51,
#   'number_of_trades': 4,
#   'volume': 207,
#   'volume_weighted_average': 142.5103,
#   'time': datetime.datetime(2024, 1, 9, 21, 29, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 3,
#   'volume': 324,
#   'volume_weighted_average': 142.5,
#   'time': datetime.datetime(2024, 1, 9, 21, 30, tzinfo=<UTC>)},
#  {'open_price': 142.51,
#   'close_price': 142.51,
#   'high_price': 142.51,
#   'low_price': 142.51,
#   'number_of_trades': 7,
#   'volume': 252,
#   'volume_weighted_average': 142.512,
#   'time': datetime.datetime(2024, 1, 9, 21, 32, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 4,
#   'volume': 118,
#   'volume_weighted_average': 142.5195,
#   'time': datetime.datetime(2024, 1, 9, 21, 34, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 5,
#   'volume': 320,
#   'volume_weighted_average': 142.5215,
#   'time': datetime.datetime(2024, 1, 9, 21, 36, tzinfo=<UTC>)},
#  {'open_price': 142.5298,
#   'close_price': 142.5298,
#   'high_price': 142.5298,
#   'low_price': 142.5298,
#   'number_of_trades': 8,
#   'volume': 640,
#   'volume_weighted_average': 142.5288,
#   'time': datetime.datetime(2024, 1, 9, 21, 37, tzinfo=<UTC>)},
#  {'open_price': 142.53,
#   'close_price': 142.53,
#   'high_price': 142.53,
#   'low_price': 142.53,
#   'number_of_trades': 4,
#   'volume': 608,
#   'volume_weighted_average': 142.5297,
#   'time': datetime.datetime(2024, 1, 9, 21, 38, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.49,
#   'high_price': 142.51,
#   'low_price': 142.27,
#   'number_of_trades': 50,
#   'volume': 5144,
#   'volume_weighted_average': 142.436,
#   'time': datetime.datetime(2024, 1, 9, 21, 39, tzinfo=<UTC>)},
#  {'open_price': 142.51,
#   'close_price': 142.51,
#   'high_price': 142.51,
#   'low_price': 142.51,
#   'number_of_trades': 14,
#   'volume': 328,
#   'volume_weighted_average': 142.5062,
#   'time': datetime.datetime(2024, 1, 9, 21, 40, tzinfo=<UTC>)},
#  {'open_price': 142.48,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.48,
#   'number_of_trades': 7,
#   'volume': 633,
#   'volume_weighted_average': 142.4897,
#   'time': datetime.datetime(2024, 1, 9, 21, 42, tzinfo=<UTC>)},
#  {'open_price': 142.49,
#   'close_price': 142.49,
#   'high_price': 142.49,
#   'low_price': 142.49,
#   'number_of_trades': 5,
#   'volume': 134,
#   'volume_weighted_average': 142.4968,
#   'time': datetime.datetime(2024, 1, 9, 21, 43, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 4,
#   'volume': 221,
#   'volume_weighted_average': 142.499,
#   'time': datetime.datetime(2024, 1, 9, 21, 45, tzinfo=<UTC>)},
#  {'open_price': 142.49,
#   'close_price': 142.49,
#   'high_price': 142.49,
#   'low_price': 142.49,
#   'number_of_trades': 5,
#   'volume': 179,
#   'volume_weighted_average': 142.4856,
#   'time': datetime.datetime(2024, 1, 9, 21, 48, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 3,
#   'volume': 331,
#   'volume_weighted_average': 142.4996,
#   'time': datetime.datetime(2024, 1, 9, 21, 59, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 2,
#   'volume': 256807,
#   'volume_weighted_average': 142.5599,
#   'time': datetime.datetime(2024, 1, 9, 22, 4, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 7,
#   'volume': 1271,
#   'volume_weighted_average': 142.5,
#   'time': datetime.datetime(2024, 1, 9, 22, 5, tzinfo=<UTC>)},
#  {'open_price': 142.5193,
#   'close_price': 142.5193,
#   'high_price': 142.5193,
#   'low_price': 142.5193,
#   'number_of_trades': 1,
#   'volume': 3000,
#   'volume_weighted_average': 142.5193,
#   'time': datetime.datetime(2024, 1, 9, 22, 10, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 4,
#   'volume': 222,
#   'volume_weighted_average': 142.5,
#   'time': datetime.datetime(2024, 1, 9, 22, 11, tzinfo=<UTC>)},
#  {'open_price': 142.5199,
#   'close_price': 142.49,
#   'high_price': 142.5199,
#   'low_price': 142.49,
#   'number_of_trades': 9,
#   'volume': 1190,
#   'volume_weighted_average': 142.511,
#   'time': datetime.datetime(2024, 1, 9, 22, 12, tzinfo=<UTC>)},
#  {'open_price': 142.4901,
#   'close_price': 142.4901,
#   'high_price': 142.4901,
#   'low_price': 142.4901,
#   'number_of_trades': 2,
#   'volume': 351,
#   'volume_weighted_average': 142.4901,
#   'time': datetime.datetime(2024, 1, 9, 22, 13, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.49,
#   'high_price': 142.5,
#   'low_price': 142.49,
#   'number_of_trades': 3,
#   'volume': 300,
#   'volume_weighted_average': 142.4933,
#   'time': datetime.datetime(2024, 1, 9, 22, 15, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 5,
#   'volume': 1382,
#   'volume_weighted_average': 142.52,
#   'time': datetime.datetime(2024, 1, 9, 22, 22, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 3,
#   'volume': 176,
#   'volume_weighted_average': 142.4999,
#   'time': datetime.datetime(2024, 1, 9, 22, 23, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 2,
#   'volume': 163,
#   'volume_weighted_average': 142.5002,
#   'time': datetime.datetime(2024, 1, 9, 22, 24, tzinfo=<UTC>)},
#  {'open_price': 142.51,
#   'close_price': 142.49,
#   'high_price': 142.51,
#   'low_price': 142.49,
#   'number_of_trades': 2,
#   'volume': 350,
#   'volume_weighted_average': 142.5043,
#   'time': datetime.datetime(2024, 1, 9, 22, 26, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 142.4999,
#   'time': datetime.datetime(2024, 1, 9, 22, 37, tzinfo=<UTC>)},
#  {'open_price': 142.48,
#   'close_price': 142.48,
#   'high_price': 142.48,
#   'low_price': 142.48,
#   'number_of_trades': 5,
#   'volume': 168,
#   'volume_weighted_average': 142.4829,
#   'time': datetime.datetime(2024, 1, 9, 22, 39, tzinfo=<UTC>)},
#  {'open_price': 142.46,
#   'close_price': 142.46,
#   'high_price': 142.46,
#   'low_price': 142.46,
#   'number_of_trades': 3,
#   'volume': 300,
#   'volume_weighted_average': 142.4633,
#   'time': datetime.datetime(2024, 1, 9, 22, 43, tzinfo=<UTC>)},
#  {'open_price': 142.46,
#   'close_price': 142.46,
#   'high_price': 142.46,
#   'low_price': 142.46,
#   'number_of_trades': 4,
#   'volume': 111,
#   'volume_weighted_average': 142.4607,
#   'time': datetime.datetime(2024, 1, 9, 22, 48, tzinfo=<UTC>)},
#  {'open_price': 142.49,
#   'close_price': 142.49,
#   'high_price': 142.49,
#   'low_price': 142.49,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 142.49,
#   'time': datetime.datetime(2024, 1, 9, 22, 50, tzinfo=<UTC>)},
#  {'open_price': 142.48,
#   'close_price': 142.48,
#   'high_price': 142.48,
#   'low_price': 142.48,
#   'number_of_trades': 2,
#   'volume': 121,
#   'volume_weighted_average': 142.4808,
#   'time': datetime.datetime(2024, 1, 9, 23, 1, tzinfo=<UTC>)},
#  {'open_price': 142.45,
#   'close_price': 142.44,
#   'high_price': 142.45,
#   'low_price': 142.44,
#   'number_of_trades': 9,
#   'volume': 515,
#   'volume_weighted_average': 142.4556,
#   'time': datetime.datetime(2024, 1, 9, 23, 2, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 142.52,
#   'time': datetime.datetime(2024, 1, 9, 23, 22, tzinfo=<UTC>)},
#  {'open_price': 142.4999,
#   'close_price': 142.4999,
#   'high_price': 142.4999,
#   'low_price': 142.4999,
#   'number_of_trades': 2,
#   'volume': 280,
#   'volume_weighted_average': 142.4998,
#   'time': datetime.datetime(2024, 1, 9, 23, 25, tzinfo=<UTC>)},
#  {'open_price': 142.5,
#   'close_price': 142.5,
#   'high_price': 142.5,
#   'low_price': 142.5,
#   'number_of_trades': 2,
#   'volume': 201,
#   'volume_weighted_average': 142.5,
#   'time': datetime.datetime(2024, 1, 9, 23, 42, tzinfo=<UTC>)},
#  {'open_price': 142.47,
#   'close_price': 142.47,
#   'high_price': 142.47,
#   'low_price': 142.47,
#   'number_of_trades': 1,
#   'volume': 140,
#   'volume_weighted_average': 142.47,
#   'time': datetime.datetime(2024, 1, 9, 23, 49, tzinfo=<UTC>)},
#  {'open_price': 142.46,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.46,
#   'number_of_trades': 12,
#   'volume': 441,
#   'volume_weighted_average': 142.5023,
#   'time': datetime.datetime(2024, 1, 9, 23, 50, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 4,
#   'volume': 705,
#   'volume_weighted_average': 142.52,
#   'time': datetime.datetime(2024, 1, 9, 23, 55, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 6,
#   'volume': 312,
#   'volume_weighted_average': 142.5006,
#   'time': datetime.datetime(2024, 1, 9, 23, 59, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 7,
#   'volume': 400,
#   'volume_weighted_average': 142.5136,
#   'time': datetime.datetime(2024, 1, 10, 0, 0, tzinfo=<UTC>)},
#  {'open_price': 142.52,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.52,
#   'number_of_trades': 2,
#   'volume': 505,
#   'volume_weighted_average': 142.52,
#   'time': datetime.datetime(2024, 1, 10, 0, 2, tzinfo=<UTC>)},
#  {'open_price': 142.48,
#   'close_price': 142.52,
#   'high_price': 142.52,
#   'low_price': 142.48,
#   'number_of_trades': 5,
#   'volume': 1755,
#   'volume_weighted_average': 142.5137,
#   'time': datetime.datetime(2024, 1, 10, 0, 3, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.55,
#   'high_price': 142.55,
#   'low_price': 142.55,
#   'number_of_trades': 7,
#   'volume': 1110,
#   'volume_weighted_average': 142.55,
#   'time': datetime.datetime(2024, 1, 10, 0, 4, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.55,
#   'high_price': 142.55,
#   'low_price': 142.55,
#   'number_of_trades': 5,
#   'volume': 485,
#   'volume_weighted_average': 142.5494,
#   'time': datetime.datetime(2024, 1, 10, 0, 5, tzinfo=<UTC>)},
#  {'open_price': 142.55,
#   'close_price': 142.56,
#   'high_price': 142.56,
#   'low_price': 142.55,
#   'number_of_trades': 21,
#   'volume': 3807,
#   'volume_weighted_average': 142.5553,
#   'time': datetime.datetime(2024, 1, 10, 0, 6, tzinfo=<UTC>)},
#  {'open_price': 142.56,
#   'close_price': 142.58,
#   'high_price': 142.58,
#   'low_price': 142.56,
#   'number_of_trades': 9,
#   'volume': 627,
#   'volume_weighted_average': 142.5664,
#   'time': datetime.datetime(2024, 1, 10, 0, 7, tzinfo=<UTC>)},
#  {'open_price': 142.59,
#   'close_price': 142.59,
#   'high_price': 142.59,
#   'low_price': 142.59,
#   'number_of_trades': 10,
#   'volume': 201,
#   'volume_weighted_average': 142.5876,
#   'time': datetime.datetime(2024, 1, 10, 0, 10, tzinfo=<UTC>)},
#  {'open_price': 142.58,
#   'close_price': 142.58,
#   'high_price': 142.58,
#   'low_price': 142.58,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 142.5799,
#   'time': datetime.datetime(2024, 1, 10, 0, 11, tzinfo=<UTC>)},
#  {'open_price': 142.57,
#   'close_price': 142.57,
#   'high_price': 142.57,
#   'low_price': 142.57,
#   'number_of_trades': 6,
#   'volume': 202,
#   'volume_weighted_average': 142.57,
#   'time': datetime.datetime(2024, 1, 10, 0, 13, tzinfo=<UTC>)},
#  {'open_price': 142.58,
#   'close_price': 142.58,
#   'high_price': 142.58,
#   'low_price': 142.58,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 142.5799,
#   'time': datetime.datetime(2024, 1, 10, 0, 21, tzinfo=<UTC>)},
#  {'open_price': 142.59,
#   'close_price': 142.59,
#   'high_price': 142.59,
#   'low_price': 142.59,
#   'number_of_trades': 7,
#   'volume': 407,
#   'volume_weighted_average': 142.5898,
#   'time': datetime.datetime(2024, 1, 10, 0, 23, tzinfo=<UTC>)},
#  {'open_price': 142.62,
#   'close_price': 142.62,
#   'high_price': 142.62,
#   'low_price': 142.62,
#   'number_of_trades': 10,
#   'volume': 793,
#   'volume_weighted_average': 142.6192,
#   'time': datetime.datetime(2024, 1, 10, 0, 33, tzinfo=<UTC>)},
#  {'open_price': 142.65,
#   'close_price': 142.65,
#   'high_price': 142.65,
#   'low_price': 142.65,
#   'number_of_trades': 4,
#   'volume': 257,
#   'volume_weighted_average': 142.6316,
#   'time': datetime.datetime(2024, 1, 10, 0, 34, tzinfo=<UTC>)},
#  {'open_price': 142.65,
#   'close_price': 142.65,
#   'high_price': 142.65,
#   'low_price': 142.65,
#   'number_of_trades': 3,
#   'volume': 161,
#   'volume_weighted_average': 142.6495,
#   'time': datetime.datetime(2024, 1, 10, 0, 36, tzinfo=<UTC>)},
#  {'open_price': 142.58,
#   'close_price': 142.58,
#   'high_price': 142.58,
#   'low_price': 142.58,
#   'number_of_trades': 1,
#   'volume': 150,
#   'volume_weighted_average': 142.58,
#   'time': datetime.datetime(2024, 1, 10, 0, 50, tzinfo=<UTC>)},
#  {'open_price': 142.56,
#   'close_price': 142.56,
#   'high_price': 142.56,
#   'low_price': 142.56,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 142.5604,
#   'time': datetime.datetime(2024, 1, 10, 0, 51, tzinfo=<UTC>)},
#  {'open_price': 142.59,
#   'close_price': 142.59,
#   'high_price': 142.59,
#   'low_price': 142.59,
#   'number_of_trades': 5,
#   'volume': 185,
#   'volume_weighted_average': 142.6003,
#   'time': datetime.datetime(2024, 1, 10, 0, 55, tzinfo=<UTC>)}]
